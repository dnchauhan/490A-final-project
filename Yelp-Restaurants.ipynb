# %% [markdown]
# ### Yelp Restaurant Data through Yelp Fusion API
#
# Followed the folowing [medium article](https://medium.com/web-mining-is688-spring-2021/yelp-restaurants-web-scraping-analysis-fcf54cf519f1) extract restaurants from the various businesses on Yelp using Yelp's Fusion API.
#
# The Dataset contains the following 5 json files:
#
# - business.json
# - review.json
# - user.json
# - checkin.json
# - tip.json
# - photo.json
#
# We will use the Yelp Fusion API to make requests through Postman to get business id's from business.json and mapping it to the text reviews and star ratings from review.json to gather the data for our project.
#
# The goal is to collect 15k reviews with 5k reviews for each class (positve, negative, neutral). The reviews will be classified into one of the three classes by their respective star ratings (1-2: positive, 3: negative, 4-5: positive).

# %%
# import requests

# url = "https://api.yelp.com/v3/businesses/search?term=restaurants&location=Boston"
# url2 = "https://api.yelp.com/v3/businesses/search?term=restaurants&location=New York"

# payload={}
# headers = {
#   'Authorization': 'Bearer [auth_key]'
# }

# res_BOS = requests.request("GET", url, headers=headers, data=payload)
# res_NY = requests.request("GET", url, headers=headers, data=payload)

# %%
# print(res_BOS.content)
# print(res_NY.content)

# %% [markdown]
# ### Business ID extraction from the response json's
#
# Now that we have a json containing the business details about the restaurants in Boston and New York, the next step is to extract the details that we need to get to the text reviews.
#
# We will extract the following fields from the response JSON in the form:
#
# {"businesses": [
#     {id: "gfjeru7_dhw",
#     name: "Paradise of India",
#     review_count: 1300,
#     rating: 4.5},
#     {...}
#     ]
# }

# %%
import json

bos_res = open('boston_restaurants.json', 'r')
values = json.load(bos_res)
bos_res.close()

# %%
data = {
    "businesses": [],
    "total_reviews": -1    
}

# %%
# for criteria in values['businesses']:
#     for key, value in criteria.items():
#         print(key, 'is:', value)
#     print('')

# %%
for field in values['businesses']:
    data["total_reviews"] += field["review_count"]
    res_info = {"id": None, "name": None, "review_count": None, "rating": None}
    for key,value in field.items():
        if key in res_info.keys():
            res_info[key] = value
    data["businesses"].append(res_info)
data
# Out:
# {'businesses': [{'id': 'sA2gVTJOBH7Qk32p48ENdQ',
#    'name': 'Saltie Girl',
#    'review_count': 1368,
#    'rating': 4.5},
#   {'id': 'kP1b-7BO_VhWk_0tvuA_tw',
#    'name': "Carmelina's",
#    'review_count': 2491,
#    'rating': 4.5},
#   {'id': 'xlOMKjE4omTgkI1eduWj8A',
#    'name': 'The Friendly Toast',
#    'review_count': 2038,
#    'rating': 4.0},
#   {'id': 'tKRg7pxR2Sw7aSrHTQS5mQ',
#    'name': 'Buttermilk & Bourbon',
#    'review_count': 729,
#    'rating': 4.0},
#   {'id': 'y2w6rFaO0XEiG5mFfOsiFA',
#    'name': 'Neptune Oyster',
#    'review_count': 5386,
#    'rating': 4.5},
#   {'id': 't_FFcwUutj9mIYKGw_gHsQ',
#    'name': 'The Salty Pig',
#    'review_count': 1711,
#    'rating': 4.0},
#   {'id': 'lCMN0raxlHnBFDoLgkz4sw',
#    'name': 'Milkweed',
#    'review_count': 793,
#    'rating': 4.0},
#   {'id': 'kb0VfKZKHHhvDze3JZqi0Q',
#    'name': 'Q Restaurant',
#    'review_count': 1152,
#    'rating': 4.0},
#   {'id': 'EbUZhM4fLpsWQ8fpBhhgEQ',
#    'name': "Mike & Patty's - Boston",
#    'review_count': 1867,
#    'rating': 4.5},
#   {'id': 'NYa-JphaaB41ElGsb3iawA',
#    'name': 'Toro',
#    'review_count': 2255,
#    'rating': 4.0},
#   {'id': 'lPAzwB4vPBqZmaFNH90kiQ',
#    'name': 'Cafe Bonjour',
#    'review_count': 319,
#    'rating': 4.5},
#   {'id': '2u_w3rthRzR2uEihW5BC4A',
#    'name': "Giacomo's Ristorante - Boston",
#    'review_count': 3669,
#    'rating': 4.0},
#   {'id': '9gtpqrz-5bLzf6SlhYI3vA',
#    'name': 'Nagomi Izakaya',
#    'review_count': 11,
#    'rating': 4.5},
#   {'id': 'nyy38msunExaObJOeH7j0Q',
#    'name': 'Bootleg Special',
#    'review_count': 778,
#    'rating': 4.0},
#   {'id': 'uXOVFQraz1va1TrtgiqYTg',
#    'name': 'The Daily Catch',
#    'review_count': 1719,
#    'rating': 4.0},
#   {'id': 'mP1EdIafQKMuOm9O4PzAfA',
#    'name': 'Barcelona Wine Bar South End',
#    'review_count': 1190,
#    'rating': 4.5},
#   {'id': 'E3Qqa99qFy1oeGMv0wPBBQ',
#    'name': 'Tora Japanese Restaurant',
#    'review_count': 518,
#    'rating': 4.5},
#   {'id': 'nIS4O-TwLYkA_P1Cu0SfhA',
#    'name': "Yvonne's",
#    'review_count': 1096,
#    'rating': 4.0},
#   {'id': 'AGR_kBvN__I7aTl0rBywAg',
#    'name': 'Atlantic Fish Co',
#    'review_count': 2720,
#    'rating': 4.0},
#   {'id': 'xZ22_0eJOgaiKqIhoSHrPw',
#    'name': 'Bostonia Public House',
#    'review_count': 1565,
#    'rating': 4.0}],
#  'total_reviews': 33374}

# %%
NY_res = open('NY_restaurants.json', 'r')
values = json.load(NY_res)
NY_res.close()

# for criteria in values['businesses']:
#     for key, value in criteria.items():
#         print(key, 'is:', value)
#     print('')
# Out:
# id is: fVbUVAiLiGgLA_nxBFxyww
# alias is: thursday-kitchen-new-york
# name is: Thursday Kitchen
# image_url is: https://s3-media4.fl.yelpcdn.com/bphoto/nXO8M-d-XTamNmc0BpXWtA/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/thursday-kitchen-new-york?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 1478
# categories is: [{'alias': 'korean', 'title': 'Korean'}, {'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}]
# rating is: 4.5
# coordinates is: {'latitude': 40.7275, 'longitude': -73.9838}
# transactions is: ['pickup', 'delivery']
# price is: $$
# location is: {'address1': '424 E 9th St', 'address2': None, 'address3': '', 'city': 'New York', 'zip_code': '10009', 'country': 'US', 'state': 'NY', 'display_address': ['424 E 9th St', 'New York, NY 10009']}
# phone is:
# display_phone is:
# distance is: 2613.195773628755
#
# id is: J3NT61-AH5d5Gu5tFJhYSw
# alias is: the-cabin-nyc-new-york-2
# name is: The Cabin NYC
# image_url is: https://s3-media2.fl.yelpcdn.com/bphoto/pXi18yJuoYy_Nll-nclezQ/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/the-cabin-nyc-new-york-2?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 353
# categories is: [{'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}]
# rating is: 4.0
# coordinates is: {'latitude': 40.72393, 'longitude': -73.98383}
# transactions is: ['restaurant_reservation', 'pickup', 'delivery']
# price is: $$
# location is: {'address1': '205 E 4th St', 'address2': None, 'address3': '', 'city': 'New York', 'zip_code': '10009', 'country': 'US', 'state': 'NY', 'display_address': ['205 E 4th St', 'New York, NY 10009']}
# phone is: +12127770454
# display_phone is: (212) 777-0454
# distance is: 2240.673403602855
#
# id is: qEe7nIhPfEL6L0-VYhWRrA
# alias is: raku-new-york-6
# name is: Raku
# image_url is: https://s3-media1.fl.yelpcdn.com/bphoto/EQsQlLlKQjziOrGsEblCbQ/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/raku-new-york-6?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 555
# categories is: [{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'noodles', 'title': 'Noodles'}]
# rating is: 4.5
# coordinates is: {'latitude': 40.72728, 'longitude': -74.00252}
# transactions is: ['pickup', 'delivery']
# price is: $$
# location is: {'address1': '48 Macdougal St', 'address2': None, 'address3': '', 'city': 'New York', 'zip_code': '10012', 'country': 'US', 'state': 'NY', 'display_address': ['48 Macdougal St', 'New York, NY 10012']}
# phone is: +12129894797
# display_phone is: (212) 989-4797
# distance is: 2522.2670460297
#
# id is: 0CjK3esfpFcxIopebzjFxA
# alias is: joes-shanghai-new-york-2
# name is: Joe's Shanghai
# image_url is: https://s3-media4.fl.yelpcdn.com/bphoto/KRvabBPGaQikcpSD6vO2bg/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/joes-shanghai-new-york-2?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 6495
# categories is: [{'alias': 'shanghainese', 'title': 'Shanghainese'}, {'alias': 'seafood', 'title': 'Seafood'}, {'alias': 'noodles', 'title': 'Noodles'}]
# rating is: 4.0
# coordinates is: {'latitude': 40.7156608, 'longitude': -73.9967012}
# transactions is: ['pickup', 'delivery']
# price is: $$
# location is: {'address1': '46 Bowery St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10013', 'country': 'US', 'state': 'NY', 'display_address': ['46 Bowery St', 'New York, NY 10013']}
# phone is: +12122338888
# display_phone is: (212) 233-8888
# distance is: 1153.9482385806896
#
# id is: ETgJqJHV7BW6pIr9Ox74sA
# alias is: amélie-new-york
# name is: Amélie
# image_url is: https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 2759
# categories is: [{'alias': 'french', 'title': 'French'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}]
# rating is: 4.5
# coordinates is: {'latitude': 40.7327, 'longitude': -73.99766}
# transactions is: ['pickup', 'delivery']
# price is: $$$
# location is: {'address1': '22 W 8th St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10011', 'country': 'US', 'state': 'NY', 'display_address': ['22 W 8th St', 'New York, NY 10011']}
# phone is: +12125332962
# display_phone is: (212) 533-2962
# distance is: 3038.8699032940094
#
# id is: B3_K2kUVbYOU0VaLcj_LTw
# alias is: thai-villa-new-york-2
# name is: Thai Villa
# image_url is: https://s3-media3.fl.yelpcdn.com/bphoto/XKvKGgVuj4_jhqHPVQj4_A/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 3890
# categories is: [{'alias': 'thai', 'title': 'Thai'}]
# rating is: 4.5
# coordinates is: {'latitude': 40.73902, 'longitude': -73.99065}
# transactions is: ['pickup', 'delivery']
# price is: $$
# location is: {'address1': '5 E 19th St', 'address2': 'G Floor', 'address3': '', 'city': 'New York', 'zip_code': '10003', 'country': 'US', 'state': 'NY', 'display_address': ['5 E 19th St', 'G Floor', 'New York, NY 10003']}
# phone is: +12128029999
# display_phone is: (212) 802-9999
# distance is: 3744.570399827637
#
# id is: FlZ1zdVEKWv7dwqm8Uw8-w
# alias is: raku-new-york-7
# name is: Raku
# image_url is: https://s3-media4.fl.yelpcdn.com/bphoto/GEbZnH1jR4n7D5WOJ3urPg/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/raku-new-york-7?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 1227
# categories is: [{'alias': 'japanese', 'title': 'Japanese'}, {'alias': 'noodles', 'title': 'Noodles'}]
# rating is: 4.5
# coordinates is: {'latitude': 40.7264988089246, 'longitude': -73.9866526052356}
# transactions is: ['pickup', 'delivery']
# price is: $$
# location is: {'address1': '342 E 6th St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10003', 'country': 'US', 'state': 'NY', 'display_address': ['342 E 6th St', 'New York, NY 10003']}
# phone is: +12122281324
# display_phone is: (212) 228-1324
# distance is: 2428.0392489129867
#
# id is: liZmIO0FqZwslLJfLDkfgw
# alias is: wayla-new-york
# name is: Wayla
# image_url is: https://s3-media1.fl.yelpcdn.com/bphoto/Se9IRHfGW8z9-292HJyKsQ/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/wayla-new-york?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 420
# categories is: [{'alias': 'thai', 'title': 'Thai'}]
# rating is: 4.5
# coordinates is: {'latitude': 40.7183, 'longitude': -73.9926038}
# transactions is: ['delivery']
# price is: $$
# location is: {'address1': '100 Forsyth St', 'address2': 'Basement', 'address3': None, 'city': 'New York', 'zip_code': '10002', 'country': 'US', 'state': 'NY', 'display_address': ['100 Forsyth St', 'Basement', 'New York, NY 10002']}
# phone is: +12122062500
# display_phone is: (212) 206-2500
# distance is: 1436.4990587768912
#
# id is: jjJc_CrkB2HodEinB6cWww
# alias is: lovemama-new-york
# name is: LoveMama
# image_url is: https://s3-media1.fl.yelpcdn.com/bphoto/bLlFKTlVuLfmF-lIDGIjZA/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/lovemama-new-york?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 5622
# categories is: [{'alias': 'thai', 'title': 'Thai'}, {'alias': 'malaysian', 'title': 'Malaysian'}, {'alias': 'vietnamese', 'title': 'Vietnamese'}]
# rating is: 4.5
# coordinates is: {'latitude': 40.730408722512074, 'longitude': -73.98612673033213}
# transactions is: ['pickup', 'delivery']
# price is: $$
# location is: {'address1': '174 2nd Ave', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10003', 'country': 'US', 'state': 'NY', 'display_address': ['174 2nd Ave', 'New York, NY 10003']}
# phone is: +12122545370
# display_phone is: (212) 254-5370
# distance is: 2859.902795118878
#
# id is: WG639VkTjmK5dzydd1BBJA
# alias is: rubirosa-new-york-2
# name is: Rubirosa
# image_url is: https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 2489
# categories is: [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'pizza', 'title': 'Pizza'}]
# rating is: 4.5
# coordinates is: {'latitude': 40.722766, 'longitude': -73.996233}
# transactions is: ['pickup', 'delivery']
# price is: $$
# location is: {'address1': '235 Mulberry St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10012', 'country': 'US', 'state': 'NY', 'display_address': ['235 Mulberry St', 'New York, NY 10012']}
# phone is: +12129650500
# display_phone is: (212) 965-0500
# distance is: 1932.9467701334759
#
# id is: ysqgdbSrezXgVwER2kQWKA
# alias is: julianas-brooklyn-3
# name is: Juliana's
# image_url is: https://s3-media2.fl.yelpcdn.com/bphoto/clscwgOF9_Ecq-Rwsq7jyQ/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/julianas-brooklyn-3?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 2355
# categories is: [{'alias': 'pizza', 'title': 'Pizza'}]
# rating is: 4.5
# coordinates is: {'latitude': 40.70274718768062, 'longitude': -73.99343490196397}
# transactions is: ['delivery']
# price is: $$
# location is: {'address1': '19 Old Fulton St', 'address2': '', 'address3': '', 'city': 'Brooklyn', 'zip_code': '11201', 'country': 'US', 'state': 'NY', 'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']}
# phone is: +17185966700
# display_phone is: (718) 596-6700
# distance is: 308.56984360837544
#
# id is: uoT2_Wrt1noD6kZOID7tUg
# alias is: jane-new-york-2
# name is: Jane
# image_url is: https://s3-media2.fl.yelpcdn.com/bphoto/J5TWsxXoC_N7KEk2Dp-CwQ/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/jane-new-york-2?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 3239
# categories is: [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'newamerican', 'title': 'American (New)'}, {'alias': 'bars', 'title': 'Bars'}]
# rating is: 4.0
# coordinates is: {'latitude': 40.7273779, 'longitude': -74.00025}
# transactions is: ['pickup', 'delivery']
# price is: $$
# location is: {'address1': '100 W Houston St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10012', 'country': 'US', 'state': 'NY', 'display_address': ['100 W Houston St', 'New York, NY 10012']}
# phone is: +12122547000
# display_phone is: (212) 254-7000
# distance is: 2489.9758210239006
#
# id is: hdiuRS9sVZSMReZm4oV5SA
# alias is: da-andrea-new-york
# name is: Da Andrea
# image_url is: https://s3-media2.fl.yelpcdn.com/bphoto/dYaaHrqfyAn8C6x2odES-Q/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/da-andrea-new-york?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 1013
# categories is: [{'alias': 'tuscan', 'title': 'Tuscan'}]
# rating is: 4.0
# coordinates is: {'latitude': 40.736218, 'longitude': -73.99597}
# transactions is: ['restaurant_reservation', 'pickup', 'delivery']
# price is: $$
# location is: {'address1': '35 W 13th St', 'address2': '', 'address3': '', 'city': 'New York', 'zip_code': '10011', 'country': 'US', 'state': 'NY', 'display_address': ['35 W 13th St', 'New York, NY 10011']}
# phone is: +12123671979
# display_phone is: (212) 367-1979
# distance is: 3424.7293369303584
#
# id is: 16ZnHpuaaBt92XWeJHCC5A
# alias is: olio-e-piú-new-york-6
# name is: Olio e Piú
# image_url is: https://s3-media3.fl.yelpcdn.com/bphoto/W_kyLvXj7ustj-XHWYU6tQ/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/olio-e-pi%C3%BA-new-york-6?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 2892
# categories is: [{'alias': 'pizza', 'title': 'Pizza'}, {'alias': 'italian', 'title': 'Italian'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]
# rating is: 4.5
# coordinates is: {'latitude': 40.733798036104304, 'longitude': -73.99977392649927}
# transactions is: ['pickup', 'delivery']
# price is: $$
# location is: {'address1': '3 Greenwich Ave', 'address2': None, 'address3': '', 'city': 'New York', 'zip_code': '10014', 'country': 'US', 'state': 'NY', 'display_address': ['3 Greenwich Ave', 'New York, NY 10014']}
# phone is: +12122436546
# display_phone is: (212) 243-6546
# distance is: 3186.3804982206075
#
# id is: aZ_a78wVWnQnV6BdMwcFVA
# alias is: yubu-new-york
# name is: YUBU
# image_url is: https://s3-media1.fl.yelpcdn.com/bphoto/daCi1WqfzAMy2SZil2NZbg/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/yubu-new-york?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 110
# categories is: [{'alias': 'korean', 'title': 'Korean'}]
# rating is: 4.5
# coordinates is: {'latitude': 40.72702, 'longitude': -73.98608}
# transactions is: ['pickup', 'delivery']
# price is: $
# location is: {'address1': '86 E 7th St', 'address2': None, 'address3': '', 'city': 'New York', 'zip_code': '10003', 'country': 'US', 'state': 'NY', 'display_address': ['86 E 7th St', 'New York, NY 10003']}
# phone is: +16468910116
# display_phone is: (646) 891-0116
# distance is: 2497.0061450077374
#
# id is: 8SehQovJOuQDLbtzLLYLyw
# alias is: rh-rooftop-restaurant-new-york-new-york-2
# name is: RH Rooftop Restaurant New York
# image_url is: https://s3-media4.fl.yelpcdn.com/bphoto/A2Af1PeGhTFRtlCkxbogyg/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/rh-rooftop-restaurant-new-york-new-york-2?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 487
# categories is: [{'alias': 'tradamerican', 'title': 'American (Traditional)'}, {'alias': 'wine_bars', 'title': 'Wine Bars'}]
# rating is: 4.0
# coordinates is: {'latitude': 40.73985, 'longitude': -74.00639}
# transactions is: []
# price is: $$$
# location is: {'address1': '9 9th Ave', 'address2': None, 'address3': '', 'city': 'New York', 'zip_code': '10014', 'country': 'US', 'state': 'NY', 'display_address': ['9 9th Ave', 'New York, NY 10014']}
# phone is: +12122172210
# display_phone is: (212) 217-2210
# distance is: 3959.1646378131454
#
# id is: nHMDOIX32dGbfpuNUwsLNQ
# alias is: almar-brooklyn-2
# name is: AlMar
# image_url is: https://s3-media2.fl.yelpcdn.com/bphoto/T55OZs46PGolthDw3ezdCA/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/almar-brooklyn-2?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 462
# categories is: [{'alias': 'italian', 'title': 'Italian'}, {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}, {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}]
# rating is: 4.0
# coordinates is: {'latitude': 40.702662, 'longitude': -73.989177}
# transactions is: ['pickup', 'delivery']
# price is: $$
# location is: {'address1': '111 Front St', 'address2': '', 'address3': '', 'city': 'Brooklyn', 'zip_code': '11201', 'country': 'US', 'state': 'NY', 'display_address': ['111 Front St', 'Brooklyn, NY 11201']}
# phone is: +17188555288
# display_phone is: (718) 855-5288
# distance is: 530.8013177444826
#
# id is: 4FD0TAxe70nb3ngk3sXF9Q
# alias is: uluh-new-york
# name is: Uluh
# image_url is: https://s3-media3.fl.yelpcdn.com/bphoto/JQfNL8nJukKJjSQ4lRYs-g/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/uluh-new-york?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 561
# categories is: [{'alias': 'tea', 'title': 'Tea Rooms'}, {'alias': 'asianfusion', 'title': 'Asian Fusion'}, {'alias': 'szechuan', 'title': 'Szechuan'}]
# rating is: 4.5
# coordinates is: {'latitude': 40.7293403, 'longitude': -73.9866071}
# transactions is: ['restaurant_reservation', 'pickup', 'delivery']
# price is: $$$
# location is: {'address1': '152 2nd Ave', 'address2': 'Ste A', 'address3': '', 'city': 'New York', 'zip_code': '10003', 'country': 'US', 'state': 'NY', 'display_address': ['152 2nd Ave', 'Ste A', 'New York, NY 10003']}
# phone is: +19172615963
# display_phone is: (917) 261-5963
# distance is: 2734.8706531999514
#
# id is: 9fG8-RRh1rzuCKN2TmF-QQ
# alias is: 5ive-spice-new-york-2
# name is: 5ive Spice
# image_url is: https://s3-media1.fl.yelpcdn.com/bphoto/GNDdH26bue1yTqVJEawx6A/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/5ive-spice-new-york-2?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 435
# categories is: [{'alias': 'vietnamese', 'title': 'Vietnamese'}, {'alias': 'tacos', 'title': 'Tacos'}, {'alias': 'sandwiches', 'title': 'Sandwiches'}]
# rating is: 4.5
# coordinates is: {'latitude': 40.722598, 'longitude': -73.996272}
# transactions is: ['pickup', 'delivery']
# price is: $$
# location is: {'address1': '227 Mulberry St', 'address2': None, 'address3': '', 'city': 'New York', 'zip_code': '10012', 'country': 'US', 'state': 'NY', 'display_address': ['227 Mulberry St', 'New York, NY 10012']}
# phone is: +19174092605
# display_phone is: (917) 409-2605
# distance is: 1912.9622722449587
#
# id is: gtXP0CmOnBbgfnff7VXa7A
# alias is: pastis-new-york-3
# name is: Pastis
# image_url is: https://s3-media3.fl.yelpcdn.com/bphoto/3r_UeuwKiISls-w5h1xatA/o.jpg
# is_closed is: False
# url is: https://www.yelp.com/biz/pastis-new-york-3?adjust_creative=Ia1y9jsFUbkc4cDEThEkMg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=Ia1y9jsFUbkc4cDEThEkMg
# review_count is: 316
# categories is: [{'alias': 'french', 'title': 'French'}]
# rating is: 4.0
# coordinates is: {'latitude': 40.73928, 'longitude': -74.00695}
# transactions is: ['pickup', 'delivery']
# price is: $$$
# location is: {'address1': '52 Gansevoort St', 'address2': '', 'address3': None, 'city': 'New York', 'zip_code': '10014', 'country': 'US', 'state': 'NY', 'display_address': ['52 Gansevoort St', 'New York, NY 10014']}
# phone is: +12129294844
# display_phone is: (212) 929-4844
# distance is: 3907.953101477796

# %%
for field in values['businesses']:
    data["total_reviews"] += field["review_count"]
    info = {"id": None, "name": None, "review_count": None, "rating": None}
    for key,value in field.items():
        if key in res_info.keys():    
            info[key] = value
    data["businesses"].append(info)

data
# Out:
# {'businesses': [{'id': 'sA2gVTJOBH7Qk32p48ENdQ',
#    'name': 'Saltie Girl',
#    'review_count': 1368,
#    'rating': 4.5},
#   {'id': 'kP1b-7BO_VhWk_0tvuA_tw',
#    'name': "Carmelina's",
#    'review_count': 2491,
#    'rating': 4.5},
#   {'id': 'xlOMKjE4omTgkI1eduWj8A',
#    'name': 'The Friendly Toast',
#    'review_count': 2038,
#    'rating': 4.0},
#   {'id': 'tKRg7pxR2Sw7aSrHTQS5mQ',
#    'name': 'Buttermilk & Bourbon',
#    'review_count': 729,
#    'rating': 4.0},
#   {'id': 'y2w6rFaO0XEiG5mFfOsiFA',
#    'name': 'Neptune Oyster',
#    'review_count': 5386,
#    'rating': 4.5},
#   {'id': 't_FFcwUutj9mIYKGw_gHsQ',
#    'name': 'The Salty Pig',
#    'review_count': 1711,
#    'rating': 4.0},
#   {'id': 'lCMN0raxlHnBFDoLgkz4sw',
#    'name': 'Milkweed',
#    'review_count': 793,
#    'rating': 4.0},
#   {'id': 'kb0VfKZKHHhvDze3JZqi0Q',
#    'name': 'Q Restaurant',
#    'review_count': 1152,
#    'rating': 4.0},
#   {'id': 'EbUZhM4fLpsWQ8fpBhhgEQ',
#    'name': "Mike & Patty's - Boston",
#    'review_count': 1867,
#    'rating': 4.5},
#   {'id': 'NYa-JphaaB41ElGsb3iawA',
#    'name': 'Toro',
#    'review_count': 2255,
#    'rating': 4.0},
#   {'id': 'lPAzwB4vPBqZmaFNH90kiQ',
#    'name': 'Cafe Bonjour',
#    'review_count': 319,
#    'rating': 4.5},
#   {'id': '2u_w3rthRzR2uEihW5BC4A',
#    'name': "Giacomo's Ristorante - Boston",
#    'review_count': 3669,
#    'rating': 4.0},
#   {'id': '9gtpqrz-5bLzf6SlhYI3vA',
#    'name': 'Nagomi Izakaya',
#    'review_count': 11,
#    'rating': 4.5},
#   {'id': 'nyy38msunExaObJOeH7j0Q',
#    'name': 'Bootleg Special',
#    'review_count': 778,
#    'rating': 4.0},
#   {'id': 'uXOVFQraz1va1TrtgiqYTg',
#    'name': 'The Daily Catch',
#    'review_count': 1719,
#    'rating': 4.0},
#   {'id': 'mP1EdIafQKMuOm9O4PzAfA',
#    'name': 'Barcelona Wine Bar South End',
#    'review_count': 1190,
#    'rating': 4.5},
#   {'id': 'E3Qqa99qFy1oeGMv0wPBBQ',
#    'name': 'Tora Japanese Restaurant',
#    'review_count': 518,
#    'rating': 4.5},
#   {'id': 'nIS4O-TwLYkA_P1Cu0SfhA',
#    'name': "Yvonne's",
#    'review_count': 1096,
#    'rating': 4.0},
#   {'id': 'AGR_kBvN__I7aTl0rBywAg',
#    'name': 'Atlantic Fish Co',
#    'review_count': 2720,
#    'rating': 4.0},
#   {'id': 'xZ22_0eJOgaiKqIhoSHrPw',
#    'name': 'Bostonia Public House',
#    'review_count': 1565,
#    'rating': 4.0},
#   {'id': 'fVbUVAiLiGgLA_nxBFxyww',
#    'name': 'Thursday Kitchen',
#    'review_count': 1478,
#    'rating': 4.5},
#   {'id': 'J3NT61-AH5d5Gu5tFJhYSw',
#    'name': 'The Cabin NYC',
#    'review_count': 353,
#    'rating': 4.0},
#   {'id': 'qEe7nIhPfEL6L0-VYhWRrA',
#    'name': 'Raku',
#    'review_count': 555,
#    'rating': 4.5},
#   {'id': '0CjK3esfpFcxIopebzjFxA',
#    'name': "Joe's Shanghai",
#    'review_count': 6495,
#    'rating': 4.0},
#   {'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'name': 'Amélie',
#    'review_count': 2759,
#    'rating': 4.5},
#   {'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#    'name': 'Thai Villa',
#    'review_count': 3890,
#    'rating': 4.5},
#   {'id': 'FlZ1zdVEKWv7dwqm8Uw8-w',
#    'name': 'Raku',
#    'review_count': 1227,
#    'rating': 4.5},
#   {'id': 'liZmIO0FqZwslLJfLDkfgw',
#    'name': 'Wayla',
#    'review_count': 420,
#    'rating': 4.5},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'name': 'LoveMama',
#    'review_count': 5622,
#    'rating': 4.5},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'name': 'Rubirosa',
#    'review_count': 2489,
#    'rating': 4.5},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'name': "Juliana's",
#    'review_count': 2355,
#    'rating': 4.5},
#   {'id': 'uoT2_Wrt1noD6kZOID7tUg',
#    'name': 'Jane',
#    'review_count': 3239,
#    'rating': 4.0},
#   {'id': 'hdiuRS9sVZSMReZm4oV5SA',
#    'name': 'Da Andrea',
#    'review_count': 1013,
#    'rating': 4.0},
#   {'id': '16ZnHpuaaBt92XWeJHCC5A',
#    'name': 'Olio e Piú',
#    'review_count': 2892,
#    'rating': 4.5},
#   {'id': 'aZ_a78wVWnQnV6BdMwcFVA',
#    'name': 'YUBU',
#    'review_count': 110,
#    'rating': 4.5},
#   {'id': '8SehQovJOuQDLbtzLLYLyw',
#    'name': 'RH Rooftop Restaurant New York',
#    'review_count': 487,
#    'rating': 4.0},
#   {'id': 'nHMDOIX32dGbfpuNUwsLNQ',
#    'name': 'AlMar',
#    'review_count': 462,
#    'rating': 4.0},
#   {'id': '4FD0TAxe70nb3ngk3sXF9Q',
#    'name': 'Uluh',
#    'review_count': 561,
#    'rating': 4.5},
#   {'id': '9fG8-RRh1rzuCKN2TmF-QQ',
#    'name': '5ive Spice',
#    'review_count': 435,
#    'rating': 4.5},
#   {'id': 'gtXP0CmOnBbgfnff7VXa7A',
#    'name': 'Pastis',
#    'review_count': 316,
#    'rating': 4.0}],
#  'total_reviews': 70532}

# %%
LA_res = open('LA.json', 'r')
values = json.load(LA_res)
LA_res.close()

for field in values['businesses']:
    data["total_reviews"] += field["review_count"]
    res_info = {"id": None, "name": None, "review_count": None, "rating": None}
    for key,value in field.items():
        if key in res_info.keys():
            res_info[key] = value
    data["businesses"].append(res_info)
data
# Out:
# {'businesses': [{'id': 'sA2gVTJOBH7Qk32p48ENdQ',
#    'name': 'Saltie Girl',
#    'review_count': 1368,
#    'rating': 4.5},
#   {'id': 'kP1b-7BO_VhWk_0tvuA_tw',
#    'name': "Carmelina's",
#    'review_count': 2491,
#    'rating': 4.5},
#   {'id': 'xlOMKjE4omTgkI1eduWj8A',
#    'name': 'The Friendly Toast',
#    'review_count': 2038,
#    'rating': 4.0},
#   {'id': 'tKRg7pxR2Sw7aSrHTQS5mQ',
#    'name': 'Buttermilk & Bourbon',
#    'review_count': 729,
#    'rating': 4.0},
#   {'id': 'y2w6rFaO0XEiG5mFfOsiFA',
#    'name': 'Neptune Oyster',
#    'review_count': 5386,
#    'rating': 4.5},
#   {'id': 't_FFcwUutj9mIYKGw_gHsQ',
#    'name': 'The Salty Pig',
#    'review_count': 1711,
#    'rating': 4.0},
#   {'id': 'lCMN0raxlHnBFDoLgkz4sw',
#    'name': 'Milkweed',
#    'review_count': 793,
#    'rating': 4.0},
#   {'id': 'kb0VfKZKHHhvDze3JZqi0Q',
#    'name': 'Q Restaurant',
#    'review_count': 1152,
#    'rating': 4.0},
#   {'id': 'EbUZhM4fLpsWQ8fpBhhgEQ',
#    'name': "Mike & Patty's - Boston",
#    'review_count': 1867,
#    'rating': 4.5},
#   {'id': 'NYa-JphaaB41ElGsb3iawA',
#    'name': 'Toro',
#    'review_count': 2255,
#    'rating': 4.0},
#   {'id': 'lPAzwB4vPBqZmaFNH90kiQ',
#    'name': 'Cafe Bonjour',
#    'review_count': 319,
#    'rating': 4.5},
#   {'id': '2u_w3rthRzR2uEihW5BC4A',
#    'name': "Giacomo's Ristorante - Boston",
#    'review_count': 3669,
#    'rating': 4.0},
#   {'id': '9gtpqrz-5bLzf6SlhYI3vA',
#    'name': 'Nagomi Izakaya',
#    'review_count': 11,
#    'rating': 4.5},
#   {'id': 'nyy38msunExaObJOeH7j0Q',
#    'name': 'Bootleg Special',
#    'review_count': 778,
#    'rating': 4.0},
#   {'id': 'uXOVFQraz1va1TrtgiqYTg',
#    'name': 'The Daily Catch',
#    'review_count': 1719,
#    'rating': 4.0},
#   {'id': 'mP1EdIafQKMuOm9O4PzAfA',
#    'name': 'Barcelona Wine Bar South End',
#    'review_count': 1190,
#    'rating': 4.5},
#   {'id': 'E3Qqa99qFy1oeGMv0wPBBQ',
#    'name': 'Tora Japanese Restaurant',
#    'review_count': 518,
#    'rating': 4.5},
#   {'id': 'nIS4O-TwLYkA_P1Cu0SfhA',
#    'name': "Yvonne's",
#    'review_count': 1096,
#    'rating': 4.0},
#   {'id': 'AGR_kBvN__I7aTl0rBywAg',
#    'name': 'Atlantic Fish Co',
#    'review_count': 2720,
#    'rating': 4.0},
#   {'id': 'xZ22_0eJOgaiKqIhoSHrPw',
#    'name': 'Bostonia Public House',
#    'review_count': 1565,
#    'rating': 4.0},
#   {'id': 'fVbUVAiLiGgLA_nxBFxyww',
#    'name': 'Thursday Kitchen',
#    'review_count': 1478,
#    'rating': 4.5},
#   {'id': 'J3NT61-AH5d5Gu5tFJhYSw',
#    'name': 'The Cabin NYC',
#    'review_count': 353,
#    'rating': 4.0},
#   {'id': 'qEe7nIhPfEL6L0-VYhWRrA',
#    'name': 'Raku',
#    'review_count': 555,
#    'rating': 4.5},
#   {'id': '0CjK3esfpFcxIopebzjFxA',
#    'name': "Joe's Shanghai",
#    'review_count': 6495,
#    'rating': 4.0},
#   {'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'name': 'Amélie',
#    'review_count': 2759,
#    'rating': 4.5},
#   {'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#    'name': 'Thai Villa',
#    'review_count': 3890,
#    'rating': 4.5},
#   {'id': 'FlZ1zdVEKWv7dwqm8Uw8-w',
#    'name': 'Raku',
#    'review_count': 1227,
#    'rating': 4.5},
#   {'id': 'liZmIO0FqZwslLJfLDkfgw',
#    'name': 'Wayla',
#    'review_count': 420,
#    'rating': 4.5},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'name': 'LoveMama',
#    'review_count': 5622,
#    'rating': 4.5},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'name': 'Rubirosa',
#    'review_count': 2489,
#    'rating': 4.5},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'name': "Juliana's",
#    'review_count': 2355,
#    'rating': 4.5},
#   {'id': 'uoT2_Wrt1noD6kZOID7tUg',
#    'name': 'Jane',
#    'review_count': 3239,
#    'rating': 4.0},
#   {'id': 'hdiuRS9sVZSMReZm4oV5SA',
#    'name': 'Da Andrea',
#    'review_count': 1013,
#    'rating': 4.0},
#   {'id': '16ZnHpuaaBt92XWeJHCC5A',
#    'name': 'Olio e Piú',
#    'review_count': 2892,
#    'rating': 4.5},
#   {'id': 'aZ_a78wVWnQnV6BdMwcFVA',
#    'name': 'YUBU',
#    'review_count': 110,
#    'rating': 4.5},
#   {'id': '8SehQovJOuQDLbtzLLYLyw',
#    'name': 'RH Rooftop Restaurant New York',
#    'review_count': 487,
#    'rating': 4.0},
#   {'id': 'nHMDOIX32dGbfpuNUwsLNQ',
#    'name': 'AlMar',
#    'review_count': 462,
#    'rating': 4.0},
#   {'id': '4FD0TAxe70nb3ngk3sXF9Q',
#    'name': 'Uluh',
#    'review_count': 561,
#    'rating': 4.5},
#   {'id': '9fG8-RRh1rzuCKN2TmF-QQ',
#    'name': '5ive Spice',
#    'review_count': 435,
#    'rating': 4.5},
#   {'id': 'gtXP0CmOnBbgfnff7VXa7A',
#    'name': 'Pastis',
#    'review_count': 316,
#    'rating': 4.0},
#   {'id': 'z0zaCVA-p_5xTsyUZrmR0g',
#    'name': 'Republique',
#    'review_count': 5954,
#    'rating': 4.0},
#   {'id': '88kri8FhXy8b3DQ_QjSMmQ',
#    'name': "L'Antica Pizzeria Da Michele",
#    'review_count': 1137,
#    'rating': 4.5},
#   {'id': 'h1R2iKYdm2lwukzMJvJqDw',
#    'name': 'Hangari Kalguksu',
#    'review_count': 1896,
#    'rating': 4.5},
#   {'id': '25fipMHUHLZTq0sVQINi5g',
#    'name': 'The Front Yard',
#    'review_count': 2575,
#    'rating': 4.0},
#   {'id': 'WO12S4gvOYkYF8_70RWrQA',
#    'name': 'HanEuem',
#    'review_count': 50,
#    'rating': 4.5},
#   {'id': 'h2u-coGd8WWClyU3b7jf8w',
#    'name': 'Met Her At A Bar',
#    'review_count': 1856,
#    'rating': 4.5},
#   {'id': 'RVbZaawgEGmto6TxOoVBdQ',
#    'name': 'Running Goose',
#    'review_count': 1205,
#    'rating': 4.5},
#   {'id': 'cal0Wpupxj9c_AV7WzDXsw',
#    'name': 'GRANVILLE',
#    'review_count': 1717,
#    'rating': 4.5},
#   {'id': 'HuQtriV_ApipXfM8xax33w',
#    'name': 'Met Him At A Bar',
#    'review_count': 313,
#    'rating': 4.5},
#   {'id': 'fCfkMf27m2PcTWXLTrLM7Q',
#    'name': 'Fratelli Cafe',
#    'review_count': 1720,
#    'rating': 4.5},
#   {'id': 'wvaNbC16NuJIQD0g8WPjRw',
#    'name': 'TOKKI - Korean Tapas',
#    'review_count': 35,
#    'rating': 5.0},
#   {'id': 'DrToq9357afdpOyO5w0Y5w',
#    'name': 'Yup Dduk LA',
#    'review_count': 2187,
#    'rating': 4.5},
#   {'id': 'AIhWsp8yNfKZfaX9d9Yajg',
#    'name': 'Pasta Sisters',
#    'review_count': 1690,
#    'rating': 4.5},
#   {'id': 'TWHGJkTAbF22hvXeReQp9w',
#    'name': 'Kobawoo House',
#    'review_count': 1275,
#    'rating': 4.5},
#   {'id': '3C2wUqSkpY4-N0O5ArVjwQ',
#    'name': 'Yuk Dae Jang',
#    'review_count': 624,
#    'rating': 4.5},
#   {'id': 'MlmcOkwaNnxl3Zuk6HsPCQ',
#    'name': "Slurpin' Ramen Bar - Los Angeles",
#    'review_count': 4846,
#    'rating': 4.5},
#   {'id': 'kdTFcDSl9vAR-btEm1Q2uw',
#    'name': 'Bao Dim Sum House',
#    'review_count': 3151,
#    'rating': 4.0},
#   {'id': 'rr-hXB0ZqXLzUP97yftp0g',
#    'name': 'Osteria Mamma',
#    'review_count': 1717,
#    'rating': 4.0},
#   {'id': 'GKQApReu8U9hip4A2ApJ_A',
#    'name': 'Osteria La Buca',
#    'review_count': 2035,
#    'rating': 4.0},
#   {'id': 'BSUDJiaKZwbB8G-GTUst_g',
#    'name': 'Beauty & Essex',
#    'review_count': 1235,
#    'rating': 4.0}],
#  'total_reviews': 107750}

# %%
miami_res = open('miami.json', 'r')
values = json.load(miami_res)
miami_res.close()

for field in values['businesses']:
    data["total_reviews"] += field["review_count"]
    res_info = {"id": None, "name": None, "review_count": None, "rating": None}
    for key,value in field.items():
        if key in res_info.keys():
            res_info[key] = value
    data["businesses"].append(res_info)
data
# Out:
# {'businesses': [{'id': 'sA2gVTJOBH7Qk32p48ENdQ',
#    'name': 'Saltie Girl',
#    'review_count': 1368,
#    'rating': 4.5},
#   {'id': 'kP1b-7BO_VhWk_0tvuA_tw',
#    'name': "Carmelina's",
#    'review_count': 2491,
#    'rating': 4.5},
#   {'id': 'xlOMKjE4omTgkI1eduWj8A',
#    'name': 'The Friendly Toast',
#    'review_count': 2038,
#    'rating': 4.0},
#   {'id': 'tKRg7pxR2Sw7aSrHTQS5mQ',
#    'name': 'Buttermilk & Bourbon',
#    'review_count': 729,
#    'rating': 4.0},
#   {'id': 'y2w6rFaO0XEiG5mFfOsiFA',
#    'name': 'Neptune Oyster',
#    'review_count': 5386,
#    'rating': 4.5},
#   {'id': 't_FFcwUutj9mIYKGw_gHsQ',
#    'name': 'The Salty Pig',
#    'review_count': 1711,
#    'rating': 4.0},
#   {'id': 'lCMN0raxlHnBFDoLgkz4sw',
#    'name': 'Milkweed',
#    'review_count': 793,
#    'rating': 4.0},
#   {'id': 'kb0VfKZKHHhvDze3JZqi0Q',
#    'name': 'Q Restaurant',
#    'review_count': 1152,
#    'rating': 4.0},
#   {'id': 'EbUZhM4fLpsWQ8fpBhhgEQ',
#    'name': "Mike & Patty's - Boston",
#    'review_count': 1867,
#    'rating': 4.5},
#   {'id': 'NYa-JphaaB41ElGsb3iawA',
#    'name': 'Toro',
#    'review_count': 2255,
#    'rating': 4.0},
#   {'id': 'lPAzwB4vPBqZmaFNH90kiQ',
#    'name': 'Cafe Bonjour',
#    'review_count': 319,
#    'rating': 4.5},
#   {'id': '2u_w3rthRzR2uEihW5BC4A',
#    'name': "Giacomo's Ristorante - Boston",
#    'review_count': 3669,
#    'rating': 4.0},
#   {'id': '9gtpqrz-5bLzf6SlhYI3vA',
#    'name': 'Nagomi Izakaya',
#    'review_count': 11,
#    'rating': 4.5},
#   {'id': 'nyy38msunExaObJOeH7j0Q',
#    'name': 'Bootleg Special',
#    'review_count': 778,
#    'rating': 4.0},
#   {'id': 'uXOVFQraz1va1TrtgiqYTg',
#    'name': 'The Daily Catch',
#    'review_count': 1719,
#    'rating': 4.0},
#   {'id': 'mP1EdIafQKMuOm9O4PzAfA',
#    'name': 'Barcelona Wine Bar South End',
#    'review_count': 1190,
#    'rating': 4.5},
#   {'id': 'E3Qqa99qFy1oeGMv0wPBBQ',
#    'name': 'Tora Japanese Restaurant',
#    'review_count': 518,
#    'rating': 4.5},
#   {'id': 'nIS4O-TwLYkA_P1Cu0SfhA',
#    'name': "Yvonne's",
#    'review_count': 1096,
#    'rating': 4.0},
#   {'id': 'AGR_kBvN__I7aTl0rBywAg',
#    'name': 'Atlantic Fish Co',
#    'review_count': 2720,
#    'rating': 4.0},
#   {'id': 'xZ22_0eJOgaiKqIhoSHrPw',
#    'name': 'Bostonia Public House',
#    'review_count': 1565,
#    'rating': 4.0},
#   {'id': 'fVbUVAiLiGgLA_nxBFxyww',
#    'name': 'Thursday Kitchen',
#    'review_count': 1478,
#    'rating': 4.5},
#   {'id': 'J3NT61-AH5d5Gu5tFJhYSw',
#    'name': 'The Cabin NYC',
#    'review_count': 353,
#    'rating': 4.0},
#   {'id': 'qEe7nIhPfEL6L0-VYhWRrA',
#    'name': 'Raku',
#    'review_count': 555,
#    'rating': 4.5},
#   {'id': '0CjK3esfpFcxIopebzjFxA',
#    'name': "Joe's Shanghai",
#    'review_count': 6495,
#    'rating': 4.0},
#   {'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'name': 'Amélie',
#    'review_count': 2759,
#    'rating': 4.5},
#   {'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#    'name': 'Thai Villa',
#    'review_count': 3890,
#    'rating': 4.5},
#   {'id': 'FlZ1zdVEKWv7dwqm8Uw8-w',
#    'name': 'Raku',
#    'review_count': 1227,
#    'rating': 4.5},
#   {'id': 'liZmIO0FqZwslLJfLDkfgw',
#    'name': 'Wayla',
#    'review_count': 420,
#    'rating': 4.5},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'name': 'LoveMama',
#    'review_count': 5622,
#    'rating': 4.5},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'name': 'Rubirosa',
#    'review_count': 2489,
#    'rating': 4.5},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'name': "Juliana's",
#    'review_count': 2355,
#    'rating': 4.5},
#   {'id': 'uoT2_Wrt1noD6kZOID7tUg',
#    'name': 'Jane',
#    'review_count': 3239,
#    'rating': 4.0},
#   {'id': 'hdiuRS9sVZSMReZm4oV5SA',
#    'name': 'Da Andrea',
#    'review_count': 1013,
#    'rating': 4.0},
#   {'id': '16ZnHpuaaBt92XWeJHCC5A',
#    'name': 'Olio e Piú',
#    'review_count': 2892,
#    'rating': 4.5},
#   {'id': 'aZ_a78wVWnQnV6BdMwcFVA',
#    'name': 'YUBU',
#    'review_count': 110,
#    'rating': 4.5},
#   {'id': '8SehQovJOuQDLbtzLLYLyw',
#    'name': 'RH Rooftop Restaurant New York',
#    'review_count': 487,
#    'rating': 4.0},
#   {'id': 'nHMDOIX32dGbfpuNUwsLNQ',
#    'name': 'AlMar',
#    'review_count': 462,
#    'rating': 4.0},
#   {'id': '4FD0TAxe70nb3ngk3sXF9Q',
#    'name': 'Uluh',
#    'review_count': 561,
#    'rating': 4.5},
#   {'id': '9fG8-RRh1rzuCKN2TmF-QQ',
#    'name': '5ive Spice',
#    'review_count': 435,
#    'rating': 4.5},
#   {'id': 'gtXP0CmOnBbgfnff7VXa7A',
#    'name': 'Pastis',
#    'review_count': 316,
#    'rating': 4.0},
#   {'id': 'z0zaCVA-p_5xTsyUZrmR0g',
#    'name': 'Republique',
#    'review_count': 5954,
#    'rating': 4.0},
#   {'id': '88kri8FhXy8b3DQ_QjSMmQ',
#    'name': "L'Antica Pizzeria Da Michele",
#    'review_count': 1137,
#    'rating': 4.5},
#   {'id': 'h1R2iKYdm2lwukzMJvJqDw',
#    'name': 'Hangari Kalguksu',
#    'review_count': 1896,
#    'rating': 4.5},
#   {'id': '25fipMHUHLZTq0sVQINi5g',
#    'name': 'The Front Yard',
#    'review_count': 2575,
#    'rating': 4.0},
#   {'id': 'WO12S4gvOYkYF8_70RWrQA',
#    'name': 'HanEuem',
#    'review_count': 50,
#    'rating': 4.5},
#   {'id': 'h2u-coGd8WWClyU3b7jf8w',
#    'name': 'Met Her At A Bar',
#    'review_count': 1856,
#    'rating': 4.5},
#   {'id': 'RVbZaawgEGmto6TxOoVBdQ',
#    'name': 'Running Goose',
#    'review_count': 1205,
#    'rating': 4.5},
#   {'id': 'cal0Wpupxj9c_AV7WzDXsw',
#    'name': 'GRANVILLE',
#    'review_count': 1717,
#    'rating': 4.5},
#   {'id': 'HuQtriV_ApipXfM8xax33w',
#    'name': 'Met Him At A Bar',
#    'review_count': 313,
#    'rating': 4.5},
#   {'id': 'fCfkMf27m2PcTWXLTrLM7Q',
#    'name': 'Fratelli Cafe',
#    'review_count': 1720,
#    'rating': 4.5},
#   {'id': 'wvaNbC16NuJIQD0g8WPjRw',
#    'name': 'TOKKI - Korean Tapas',
#    'review_count': 35,
#    'rating': 5.0},
#   {'id': 'DrToq9357afdpOyO5w0Y5w',
#    'name': 'Yup Dduk LA',
#    'review_count': 2187,
#    'rating': 4.5},
#   {'id': 'AIhWsp8yNfKZfaX9d9Yajg',
#    'name': 'Pasta Sisters',
#    'review_count': 1690,
#    'rating': 4.5},
#   {'id': 'TWHGJkTAbF22hvXeReQp9w',
#    'name': 'Kobawoo House',
#    'review_count': 1275,
#    'rating': 4.5},
#   {'id': '3C2wUqSkpY4-N0O5ArVjwQ',
#    'name': 'Yuk Dae Jang',
#    'review_count': 624,
#    'rating': 4.5},
#   {'id': 'MlmcOkwaNnxl3Zuk6HsPCQ',
#    'name': "Slurpin' Ramen Bar - Los Angeles",
#    'review_count': 4846,
#    'rating': 4.5},
#   {'id': 'kdTFcDSl9vAR-btEm1Q2uw',
#    'name': 'Bao Dim Sum House',
#    'review_count': 3151,
#    'rating': 4.0},
#   {'id': 'rr-hXB0ZqXLzUP97yftp0g',
#    'name': 'Osteria Mamma',
#    'review_count': 1717,
#    'rating': 4.0},
#   {'id': 'GKQApReu8U9hip4A2ApJ_A',
#    'name': 'Osteria La Buca',
#    'review_count': 2035,
#    'rating': 4.0},
#   {'id': 'BSUDJiaKZwbB8G-GTUst_g',
#    'name': 'Beauty & Essex',
#    'review_count': 1235,
#    'rating': 4.0},
#   {'id': 'UXHxLN3DcDGI57uDIfCuJA',
#    'name': "Old's Havana Cuban Bar & Cocina",
#    'review_count': 1387,
#    'rating': 4.5},
#   {'id': 'SyVrRDKTGgVGNSNAbngxfw',
#    'name': 'Glass & Vine',
#    'review_count': 1122,
#    'rating': 4.0},
#   {'id': 'opz-z4k-WK0KsyyR1Vwg5A',
#    'name': 'WHISK Gourmet Food & Catering',
#    'review_count': 1253,
#    'rating': 4.5},
#   {'id': '-b4dNNCCsDMtidBcGtlM7g',
#    'name': 'Honey Uninhibited',
#    'review_count': 1126,
#    'rating': 4.0},
#   {'id': 's4LuSZ5F_1R2mRb3pOHNbQ',
#    'name': 'Mamey - Miami',
#    'review_count': 264,
#    'rating': 4.5},
#   {'id': 'O4gh_gZPp1zW9QtC1aMHWw',
#    'name': 'House of Food Porn',
#    'review_count': 102,
#    'rating': 5.0},
#   {'id': 'ix8ifP1jQM9ektdVAs19sQ',
#    'name': 'Crazy About You',
#    'review_count': 1853,
#    'rating': 4.0},
#   {'id': '_tMXqt6aeU_UajCi-Gov1Q',
#    'name': 'Black Market Miami',
#    'review_count': 304,
#    'rating': 4.0},
#   {'id': '1h8-r9cLeXxW99HhlRUnlA',
#    'name': 'CVI.CHE 105',
#    'review_count': 4269,
#    'rating': 4.5},
#   {'id': 'hZ66PVSH6Miscv2n8KxAEg',
#    'name': 'Greenstreet Cafe',
#    'review_count': 1914,
#    'rating': 4.0},
#   {'id': 'WLXQNtdVm0sPbJ3MvCIyBw',
#    'name': 'B Bistro At The Grove',
#    'review_count': 3,
#    'rating': 5.0},
#   {'id': 'V3btCvWa1flTBYt2YKea_g',
#    'name': 'Bombay Darbar',
#    'review_count': 1212,
#    'rating': 4.5},
#   {'id': 'jp8y_UlQW8KE0yAcJ1Jubg',
#    'name': 'The Fatty Crab',
#    'review_count': 154,
#    'rating': 4.5},
#   {'id': 'YQbG-8223QKr-X_Yqu-bVw',
#    'name': 'Amigo Grill & Co, Casual Steakhouse',
#    'review_count': 119,
#    'rating': 4.5},
#   {'id': 'LnyDHTiXoPRSxk7e5qPl4w',
#    'name': 'CRAFT Coral Gables',
#    'review_count': 45,
#    'rating': 4.5},
#   {'id': 'Dzk_O70dBXoKcIQQeaOqyw',
#    'name': 'Amor di Pasta - Blue Lagoon',
#    'review_count': 294,
#    'rating': 4.5},
#   {'id': 'bqTmkGBOUV6ReXWk1BVa2w',
#    'name': 'Kush by Spillover',
#    'review_count': 898,
#    'rating': 4.5},
#   {'id': 'tGKkA2Ru_tfiQdHWIjUA1A',
#    'name': 'CHICA Miami',
#    'review_count': 496,
#    'rating': 4.0},
#   {'id': 'QQnw1bFxLyamuxn4giIy9g',
#    'name': 'Barbakoa by Finka',
#    'review_count': 55,
#    'rating': 4.5},
#   {'id': 'ADe7l7J_Cn4n6ptFNXW-tg',
#    'name': 'Cebada Rooftop',
#    'review_count': 36,
#    'rating': 4.5}],
#  'total_reviews': 124656}

# %%
SF_res = open('SF.json', 'r')
values = json.load(SF_res)
SF_res.close()

for field in values['businesses']:
    data["total_reviews"] += field["review_count"]
    res_info = {"id": None, "name": None, "review_count": None, "rating": None}
    for key,value in field.items():
        if key in res_info.keys():
            res_info[key] = value
    data["businesses"].append(res_info)
data
# Out:
# {'businesses': [{'id': 'sA2gVTJOBH7Qk32p48ENdQ',
#    'name': 'Saltie Girl',
#    'review_count': 1368,
#    'rating': 4.5},
#   {'id': 'kP1b-7BO_VhWk_0tvuA_tw',
#    'name': "Carmelina's",
#    'review_count': 2491,
#    'rating': 4.5},
#   {'id': 'xlOMKjE4omTgkI1eduWj8A',
#    'name': 'The Friendly Toast',
#    'review_count': 2038,
#    'rating': 4.0},
#   {'id': 'tKRg7pxR2Sw7aSrHTQS5mQ',
#    'name': 'Buttermilk & Bourbon',
#    'review_count': 729,
#    'rating': 4.0},
#   {'id': 'y2w6rFaO0XEiG5mFfOsiFA',
#    'name': 'Neptune Oyster',
#    'review_count': 5386,
#    'rating': 4.5},
#   {'id': 't_FFcwUutj9mIYKGw_gHsQ',
#    'name': 'The Salty Pig',
#    'review_count': 1711,
#    'rating': 4.0},
#   {'id': 'lCMN0raxlHnBFDoLgkz4sw',
#    'name': 'Milkweed',
#    'review_count': 793,
#    'rating': 4.0},
#   {'id': 'kb0VfKZKHHhvDze3JZqi0Q',
#    'name': 'Q Restaurant',
#    'review_count': 1152,
#    'rating': 4.0},
#   {'id': 'EbUZhM4fLpsWQ8fpBhhgEQ',
#    'name': "Mike & Patty's - Boston",
#    'review_count': 1867,
#    'rating': 4.5},
#   {'id': 'NYa-JphaaB41ElGsb3iawA',
#    'name': 'Toro',
#    'review_count': 2255,
#    'rating': 4.0},
#   {'id': 'lPAzwB4vPBqZmaFNH90kiQ',
#    'name': 'Cafe Bonjour',
#    'review_count': 319,
#    'rating': 4.5},
#   {'id': '2u_w3rthRzR2uEihW5BC4A',
#    'name': "Giacomo's Ristorante - Boston",
#    'review_count': 3669,
#    'rating': 4.0},
#   {'id': '9gtpqrz-5bLzf6SlhYI3vA',
#    'name': 'Nagomi Izakaya',
#    'review_count': 11,
#    'rating': 4.5},
#   {'id': 'nyy38msunExaObJOeH7j0Q',
#    'name': 'Bootleg Special',
#    'review_count': 778,
#    'rating': 4.0},
#   {'id': 'uXOVFQraz1va1TrtgiqYTg',
#    'name': 'The Daily Catch',
#    'review_count': 1719,
#    'rating': 4.0},
#   {'id': 'mP1EdIafQKMuOm9O4PzAfA',
#    'name': 'Barcelona Wine Bar South End',
#    'review_count': 1190,
#    'rating': 4.5},
#   {'id': 'E3Qqa99qFy1oeGMv0wPBBQ',
#    'name': 'Tora Japanese Restaurant',
#    'review_count': 518,
#    'rating': 4.5},
#   {'id': 'nIS4O-TwLYkA_P1Cu0SfhA',
#    'name': "Yvonne's",
#    'review_count': 1096,
#    'rating': 4.0},
#   {'id': 'AGR_kBvN__I7aTl0rBywAg',
#    'name': 'Atlantic Fish Co',
#    'review_count': 2720,
#    'rating': 4.0},
#   {'id': 'xZ22_0eJOgaiKqIhoSHrPw',
#    'name': 'Bostonia Public House',
#    'review_count': 1565,
#    'rating': 4.0},
#   {'id': 'fVbUVAiLiGgLA_nxBFxyww',
#    'name': 'Thursday Kitchen',
#    'review_count': 1478,
#    'rating': 4.5},
#   {'id': 'J3NT61-AH5d5Gu5tFJhYSw',
#    'name': 'The Cabin NYC',
#    'review_count': 353,
#    'rating': 4.0},
#   {'id': 'qEe7nIhPfEL6L0-VYhWRrA',
#    'name': 'Raku',
#    'review_count': 555,
#    'rating': 4.5},
#   {'id': '0CjK3esfpFcxIopebzjFxA',
#    'name': "Joe's Shanghai",
#    'review_count': 6495,
#    'rating': 4.0},
#   {'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'name': 'Amélie',
#    'review_count': 2759,
#    'rating': 4.5},
#   {'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#    'name': 'Thai Villa',
#    'review_count': 3890,
#    'rating': 4.5},
#   {'id': 'FlZ1zdVEKWv7dwqm8Uw8-w',
#    'name': 'Raku',
#    'review_count': 1227,
#    'rating': 4.5},
#   {'id': 'liZmIO0FqZwslLJfLDkfgw',
#    'name': 'Wayla',
#    'review_count': 420,
#    'rating': 4.5},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'name': 'LoveMama',
#    'review_count': 5622,
#    'rating': 4.5},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'name': 'Rubirosa',
#    'review_count': 2489,
#    'rating': 4.5},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'name': "Juliana's",
#    'review_count': 2355,
#    'rating': 4.5},
#   {'id': 'uoT2_Wrt1noD6kZOID7tUg',
#    'name': 'Jane',
#    'review_count': 3239,
#    'rating': 4.0},
#   {'id': 'hdiuRS9sVZSMReZm4oV5SA',
#    'name': 'Da Andrea',
#    'review_count': 1013,
#    'rating': 4.0},
#   {'id': '16ZnHpuaaBt92XWeJHCC5A',
#    'name': 'Olio e Piú',
#    'review_count': 2892,
#    'rating': 4.5},
#   {'id': 'aZ_a78wVWnQnV6BdMwcFVA',
#    'name': 'YUBU',
#    'review_count': 110,
#    'rating': 4.5},
#   {'id': '8SehQovJOuQDLbtzLLYLyw',
#    'name': 'RH Rooftop Restaurant New York',
#    'review_count': 487,
#    'rating': 4.0},
#   {'id': 'nHMDOIX32dGbfpuNUwsLNQ',
#    'name': 'AlMar',
#    'review_count': 462,
#    'rating': 4.0},
#   {'id': '4FD0TAxe70nb3ngk3sXF9Q',
#    'name': 'Uluh',
#    'review_count': 561,
#    'rating': 4.5},
#   {'id': '9fG8-RRh1rzuCKN2TmF-QQ',
#    'name': '5ive Spice',
#    'review_count': 435,
#    'rating': 4.5},
#   {'id': 'gtXP0CmOnBbgfnff7VXa7A',
#    'name': 'Pastis',
#    'review_count': 316,
#    'rating': 4.0},
#   {'id': 'z0zaCVA-p_5xTsyUZrmR0g',
#    'name': 'Republique',
#    'review_count': 5954,
#    'rating': 4.0},
#   {'id': '88kri8FhXy8b3DQ_QjSMmQ',
#    'name': "L'Antica Pizzeria Da Michele",
#    'review_count': 1137,
#    'rating': 4.5},
#   {'id': 'h1R2iKYdm2lwukzMJvJqDw',
#    'name': 'Hangari Kalguksu',
#    'review_count': 1896,
#    'rating': 4.5},
#   {'id': '25fipMHUHLZTq0sVQINi5g',
#    'name': 'The Front Yard',
#    'review_count': 2575,
#    'rating': 4.0},
#   {'id': 'WO12S4gvOYkYF8_70RWrQA',
#    'name': 'HanEuem',
#    'review_count': 50,
#    'rating': 4.5},
#   {'id': 'h2u-coGd8WWClyU3b7jf8w',
#    'name': 'Met Her At A Bar',
#    'review_count': 1856,
#    'rating': 4.5},
#   {'id': 'RVbZaawgEGmto6TxOoVBdQ',
#    'name': 'Running Goose',
#    'review_count': 1205,
#    'rating': 4.5},
#   {'id': 'cal0Wpupxj9c_AV7WzDXsw',
#    'name': 'GRANVILLE',
#    'review_count': 1717,
#    'rating': 4.5},
#   {'id': 'HuQtriV_ApipXfM8xax33w',
#    'name': 'Met Him At A Bar',
#    'review_count': 313,
#    'rating': 4.5},
#   {'id': 'fCfkMf27m2PcTWXLTrLM7Q',
#    'name': 'Fratelli Cafe',
#    'review_count': 1720,
#    'rating': 4.5},
#   {'id': 'wvaNbC16NuJIQD0g8WPjRw',
#    'name': 'TOKKI - Korean Tapas',
#    'review_count': 35,
#    'rating': 5.0},
#   {'id': 'DrToq9357afdpOyO5w0Y5w',
#    'name': 'Yup Dduk LA',
#    'review_count': 2187,
#    'rating': 4.5},
#   {'id': 'AIhWsp8yNfKZfaX9d9Yajg',
#    'name': 'Pasta Sisters',
#    'review_count': 1690,
#    'rating': 4.5},
#   {'id': 'TWHGJkTAbF22hvXeReQp9w',
#    'name': 'Kobawoo House',
#    'review_count': 1275,
#    'rating': 4.5},
#   {'id': '3C2wUqSkpY4-N0O5ArVjwQ',
#    'name': 'Yuk Dae Jang',
#    'review_count': 624,
#    'rating': 4.5},
#   {'id': 'MlmcOkwaNnxl3Zuk6HsPCQ',
#    'name': "Slurpin' Ramen Bar - Los Angeles",
#    'review_count': 4846,
#    'rating': 4.5},
#   {'id': 'kdTFcDSl9vAR-btEm1Q2uw',
#    'name': 'Bao Dim Sum House',
#    'review_count': 3151,
#    'rating': 4.0},
#   {'id': 'rr-hXB0ZqXLzUP97yftp0g',
#    'name': 'Osteria Mamma',
#    'review_count': 1717,
#    'rating': 4.0},
#   {'id': 'GKQApReu8U9hip4A2ApJ_A',
#    'name': 'Osteria La Buca',
#    'review_count': 2035,
#    'rating': 4.0},
#   {'id': 'BSUDJiaKZwbB8G-GTUst_g',
#    'name': 'Beauty & Essex',
#    'review_count': 1235,
#    'rating': 4.0},
#   {'id': 'UXHxLN3DcDGI57uDIfCuJA',
#    'name': "Old's Havana Cuban Bar & Cocina",
#    'review_count': 1387,
#    'rating': 4.5},
#   {'id': 'SyVrRDKTGgVGNSNAbngxfw',
#    'name': 'Glass & Vine',
#    'review_count': 1122,
#    'rating': 4.0},
#   {'id': 'opz-z4k-WK0KsyyR1Vwg5A',
#    'name': 'WHISK Gourmet Food & Catering',
#    'review_count': 1253,
#    'rating': 4.5},
#   {'id': '-b4dNNCCsDMtidBcGtlM7g',
#    'name': 'Honey Uninhibited',
#    'review_count': 1126,
#    'rating': 4.0},
#   {'id': 's4LuSZ5F_1R2mRb3pOHNbQ',
#    'name': 'Mamey - Miami',
#    'review_count': 264,
#    'rating': 4.5},
#   {'id': 'O4gh_gZPp1zW9QtC1aMHWw',
#    'name': 'House of Food Porn',
#    'review_count': 102,
#    'rating': 5.0},
#   {'id': 'ix8ifP1jQM9ektdVAs19sQ',
#    'name': 'Crazy About You',
#    'review_count': 1853,
#    'rating': 4.0},
#   {'id': '_tMXqt6aeU_UajCi-Gov1Q',
#    'name': 'Black Market Miami',
#    'review_count': 304,
#    'rating': 4.0},
#   {'id': '1h8-r9cLeXxW99HhlRUnlA',
#    'name': 'CVI.CHE 105',
#    'review_count': 4269,
#    'rating': 4.5},
#   {'id': 'hZ66PVSH6Miscv2n8KxAEg',
#    'name': 'Greenstreet Cafe',
#    'review_count': 1914,
#    'rating': 4.0},
#   {'id': 'WLXQNtdVm0sPbJ3MvCIyBw',
#    'name': 'B Bistro At The Grove',
#    'review_count': 3,
#    'rating': 5.0},
#   {'id': 'V3btCvWa1flTBYt2YKea_g',
#    'name': 'Bombay Darbar',
#    'review_count': 1212,
#    'rating': 4.5},
#   {'id': 'jp8y_UlQW8KE0yAcJ1Jubg',
#    'name': 'The Fatty Crab',
#    'review_count': 154,
#    'rating': 4.5},
#   {'id': 'YQbG-8223QKr-X_Yqu-bVw',
#    'name': 'Amigo Grill & Co, Casual Steakhouse',
#    'review_count': 119,
#    'rating': 4.5},
#   {'id': 'LnyDHTiXoPRSxk7e5qPl4w',
#    'name': 'CRAFT Coral Gables',
#    'review_count': 45,
#    'rating': 4.5},
#   {'id': 'Dzk_O70dBXoKcIQQeaOqyw',
#    'name': 'Amor di Pasta - Blue Lagoon',
#    'review_count': 294,
#    'rating': 4.5},
#   {'id': 'bqTmkGBOUV6ReXWk1BVa2w',
#    'name': 'Kush by Spillover',
#    'review_count': 898,
#    'rating': 4.5},
#   {'id': 'tGKkA2Ru_tfiQdHWIjUA1A',
#    'name': 'CHICA Miami',
#    'review_count': 496,
#    'rating': 4.0},
#   {'id': 'QQnw1bFxLyamuxn4giIy9g',
#    'name': 'Barbakoa by Finka',
#    'review_count': 55,
#    'rating': 4.5},
#   {'id': 'ADe7l7J_Cn4n6ptFNXW-tg',
#    'name': 'Cebada Rooftop',
#    'review_count': 36,
#    'rating': 4.5},
#   {'id': 'HHtpR0RslupSQ99GIIwW5A',
#    'name': 'Marufuku Ramen',
#    'review_count': 3478,
#    'rating': 4.5},
#   {'id': 'ttarnopezxmp2ROB1N2PaA',
#    'name': 'Nopa',
#    'review_count': 5158,
#    'rating': 4.0},
#   {'id': '-DrR38H1Abk0wCyu9XOLug',
#    'name': 'Sweet Maple',
#    'review_count': 4117,
#    'rating': 4.5},
#   {'id': 'f-m7-hyFzkf0HSEeQ2s-9A',
#    'name': 'Fog Harbor Fish House',
#    'review_count': 6941,
#    'rating': 4.5},
#   {'id': '8kck3-K4zYKTJbJko0JlXQ',
#    'name': 'Farmhouse Kitchen Thai Cuisine',
#    'review_count': 2969,
#    'rating': 4.0},
#   {'id': 'XhJ6ZYagcWNHpJ1H1KvNlQ',
#    'name': 'a Mano',
#    'review_count': 1155,
#    'rating': 4.0},
#   {'id': '8dUaybEPHsZMgr1iKgqgMQ',
#    'name': 'Sotto Mare Oysteria & Seafood',
#    'review_count': 4149,
#    'rating': 4.5},
#   {'id': 'XQLmEdXoMzOpffwoFaBtaQ',
#    'name': 'Kitchen Story',
#    'review_count': 3596,
#    'rating': 4.0},
#   {'id': '_hOVIgjVRl_HzvLaa65KJg',
#    'name': 'The Snug',
#    'review_count': 281,
#    'rating': 4.0},
#   {'id': 'MaaySW1ejpwQCkr9jn1glA',
#    'name': "The Tailor's Son",
#    'review_count': 131,
#    'rating': 4.0},
#   {'id': 'BjlVE7tTp1UCEttgkM1Big',
#    'name': 'Beit Rima',
#    'review_count': 466,
#    'rating': 4.5},
#   {'id': 'dY0Mc_PHH6nLENvWmVtwxQ',
#    'name': 'Daeho Kalbijjim & Beef Soup',
#    'review_count': 1158,
#    'rating': 4.5},
#   {'id': 'XAYwAF_83becwNnSJDFkpA',
#    'name': 'Dumpling House',
#    'review_count': 252,
#    'rating': 4.5},
#   {'id': 'AtFGQccBpgEZzsy9V1330Q',
#    'name': 'Lily',
#    'review_count': 159,
#    'rating': 4.5},
#   {'id': 'TlBFKt2N2eSEBpN-UZmDBw',
#    'name': 'Parada 22',
#    'review_count': 1302,
#    'rating': 4.0},
#   {'id': '8u7pyRsCdf0DOP-Vg6MuLQ',
#    'name': 'Purple Rice',
#    'review_count': 154,
#    'rating': 4.5},
#   {'id': 'd5752S_RDb26HxoL6O06eQ',
#    'name': 'Beit Rima',
#    'review_count': 132,
#    'rating': 4.5},
#   {'id': 'eYXwVR4mMAjzkJnm5wneHQ',
#    'name': 'Burma Superstar',
#    'review_count': 6976,
#    'rating': 4.0},
#   {'id': 'B09WOy0W83Od-Xw4xEXxog',
#    'name': 'Roma Antica',
#    'review_count': 895,
#    'rating': 4.5},
#   {'id': '0A_ZUL5r8wwL1oWnzmqSog',
#    'name': 'Komaaj',
#    'review_count': 123,
#    'rating': 5.0}],
#  'total_reviews': 168248}

# %%
amherst_res = open('amherst.json', 'r')
values = json.load(amherst_res)
amherst_res.close()

for field in values['businesses']:
    data["total_reviews"] += field["review_count"]
    res_info = {"id": None, "name": None, "review_count": None, "rating": None}
    for key,value in field.items():
        if key in res_info.keys():
            res_info[key] = value
    data["businesses"].append(res_info)
data
# Out:
# {'businesses': [{'id': 'sA2gVTJOBH7Qk32p48ENdQ',
#    'name': 'Saltie Girl',
#    'review_count': 1368,
#    'rating': 4.5},
#   {'id': 'kP1b-7BO_VhWk_0tvuA_tw',
#    'name': "Carmelina's",
#    'review_count': 2491,
#    'rating': 4.5},
#   {'id': 'xlOMKjE4omTgkI1eduWj8A',
#    'name': 'The Friendly Toast',
#    'review_count': 2038,
#    'rating': 4.0},
#   {'id': 'tKRg7pxR2Sw7aSrHTQS5mQ',
#    'name': 'Buttermilk & Bourbon',
#    'review_count': 729,
#    'rating': 4.0},
#   {'id': 'y2w6rFaO0XEiG5mFfOsiFA',
#    'name': 'Neptune Oyster',
#    'review_count': 5386,
#    'rating': 4.5},
#   {'id': 't_FFcwUutj9mIYKGw_gHsQ',
#    'name': 'The Salty Pig',
#    'review_count': 1711,
#    'rating': 4.0},
#   {'id': 'lCMN0raxlHnBFDoLgkz4sw',
#    'name': 'Milkweed',
#    'review_count': 793,
#    'rating': 4.0},
#   {'id': 'kb0VfKZKHHhvDze3JZqi0Q',
#    'name': 'Q Restaurant',
#    'review_count': 1152,
#    'rating': 4.0},
#   {'id': 'EbUZhM4fLpsWQ8fpBhhgEQ',
#    'name': "Mike & Patty's - Boston",
#    'review_count': 1867,
#    'rating': 4.5},
#   {'id': 'NYa-JphaaB41ElGsb3iawA',
#    'name': 'Toro',
#    'review_count': 2255,
#    'rating': 4.0},
#   {'id': 'lPAzwB4vPBqZmaFNH90kiQ',
#    'name': 'Cafe Bonjour',
#    'review_count': 319,
#    'rating': 4.5},
#   {'id': '2u_w3rthRzR2uEihW5BC4A',
#    'name': "Giacomo's Ristorante - Boston",
#    'review_count': 3669,
#    'rating': 4.0},
#   {'id': '9gtpqrz-5bLzf6SlhYI3vA',
#    'name': 'Nagomi Izakaya',
#    'review_count': 11,
#    'rating': 4.5},
#   {'id': 'nyy38msunExaObJOeH7j0Q',
#    'name': 'Bootleg Special',
#    'review_count': 778,
#    'rating': 4.0},
#   {'id': 'uXOVFQraz1va1TrtgiqYTg',
#    'name': 'The Daily Catch',
#    'review_count': 1719,
#    'rating': 4.0},
#   {'id': 'mP1EdIafQKMuOm9O4PzAfA',
#    'name': 'Barcelona Wine Bar South End',
#    'review_count': 1190,
#    'rating': 4.5},
#   {'id': 'E3Qqa99qFy1oeGMv0wPBBQ',
#    'name': 'Tora Japanese Restaurant',
#    'review_count': 518,
#    'rating': 4.5},
#   {'id': 'nIS4O-TwLYkA_P1Cu0SfhA',
#    'name': "Yvonne's",
#    'review_count': 1096,
#    'rating': 4.0},
#   {'id': 'AGR_kBvN__I7aTl0rBywAg',
#    'name': 'Atlantic Fish Co',
#    'review_count': 2720,
#    'rating': 4.0},
#   {'id': 'xZ22_0eJOgaiKqIhoSHrPw',
#    'name': 'Bostonia Public House',
#    'review_count': 1565,
#    'rating': 4.0},
#   {'id': 'fVbUVAiLiGgLA_nxBFxyww',
#    'name': 'Thursday Kitchen',
#    'review_count': 1478,
#    'rating': 4.5},
#   {'id': 'J3NT61-AH5d5Gu5tFJhYSw',
#    'name': 'The Cabin NYC',
#    'review_count': 353,
#    'rating': 4.0},
#   {'id': 'qEe7nIhPfEL6L0-VYhWRrA',
#    'name': 'Raku',
#    'review_count': 555,
#    'rating': 4.5},
#   {'id': '0CjK3esfpFcxIopebzjFxA',
#    'name': "Joe's Shanghai",
#    'review_count': 6495,
#    'rating': 4.0},
#   {'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'name': 'Amélie',
#    'review_count': 2759,
#    'rating': 4.5},
#   {'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#    'name': 'Thai Villa',
#    'review_count': 3890,
#    'rating': 4.5},
#   {'id': 'FlZ1zdVEKWv7dwqm8Uw8-w',
#    'name': 'Raku',
#    'review_count': 1227,
#    'rating': 4.5},
#   {'id': 'liZmIO0FqZwslLJfLDkfgw',
#    'name': 'Wayla',
#    'review_count': 420,
#    'rating': 4.5},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'name': 'LoveMama',
#    'review_count': 5622,
#    'rating': 4.5},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'name': 'Rubirosa',
#    'review_count': 2489,
#    'rating': 4.5},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'name': "Juliana's",
#    'review_count': 2355,
#    'rating': 4.5},
#   {'id': 'uoT2_Wrt1noD6kZOID7tUg',
#    'name': 'Jane',
#    'review_count': 3239,
#    'rating': 4.0},
#   {'id': 'hdiuRS9sVZSMReZm4oV5SA',
#    'name': 'Da Andrea',
#    'review_count': 1013,
#    'rating': 4.0},
#   {'id': '16ZnHpuaaBt92XWeJHCC5A',
#    'name': 'Olio e Piú',
#    'review_count': 2892,
#    'rating': 4.5},
#   {'id': 'aZ_a78wVWnQnV6BdMwcFVA',
#    'name': 'YUBU',
#    'review_count': 110,
#    'rating': 4.5},
#   {'id': '8SehQovJOuQDLbtzLLYLyw',
#    'name': 'RH Rooftop Restaurant New York',
#    'review_count': 487,
#    'rating': 4.0},
#   {'id': 'nHMDOIX32dGbfpuNUwsLNQ',
#    'name': 'AlMar',
#    'review_count': 462,
#    'rating': 4.0},
#   {'id': '4FD0TAxe70nb3ngk3sXF9Q',
#    'name': 'Uluh',
#    'review_count': 561,
#    'rating': 4.5},
#   {'id': '9fG8-RRh1rzuCKN2TmF-QQ',
#    'name': '5ive Spice',
#    'review_count': 435,
#    'rating': 4.5},
#   {'id': 'gtXP0CmOnBbgfnff7VXa7A',
#    'name': 'Pastis',
#    'review_count': 316,
#    'rating': 4.0},
#   {'id': 'z0zaCVA-p_5xTsyUZrmR0g',
#    'name': 'Republique',
#    'review_count': 5954,
#    'rating': 4.0},
#   {'id': '88kri8FhXy8b3DQ_QjSMmQ',
#    'name': "L'Antica Pizzeria Da Michele",
#    'review_count': 1137,
#    'rating': 4.5},
#   {'id': 'h1R2iKYdm2lwukzMJvJqDw',
#    'name': 'Hangari Kalguksu',
#    'review_count': 1896,
#    'rating': 4.5},
#   {'id': '25fipMHUHLZTq0sVQINi5g',
#    'name': 'The Front Yard',
#    'review_count': 2575,
#    'rating': 4.0},
#   {'id': 'WO12S4gvOYkYF8_70RWrQA',
#    'name': 'HanEuem',
#    'review_count': 50,
#    'rating': 4.5},
#   {'id': 'h2u-coGd8WWClyU3b7jf8w',
#    'name': 'Met Her At A Bar',
#    'review_count': 1856,
#    'rating': 4.5},
#   {'id': 'RVbZaawgEGmto6TxOoVBdQ',
#    'name': 'Running Goose',
#    'review_count': 1205,
#    'rating': 4.5},
#   {'id': 'cal0Wpupxj9c_AV7WzDXsw',
#    'name': 'GRANVILLE',
#    'review_count': 1717,
#    'rating': 4.5},
#   {'id': 'HuQtriV_ApipXfM8xax33w',
#    'name': 'Met Him At A Bar',
#    'review_count': 313,
#    'rating': 4.5},
#   {'id': 'fCfkMf27m2PcTWXLTrLM7Q',
#    'name': 'Fratelli Cafe',
#    'review_count': 1720,
#    'rating': 4.5},
#   {'id': 'wvaNbC16NuJIQD0g8WPjRw',
#    'name': 'TOKKI - Korean Tapas',
#    'review_count': 35,
#    'rating': 5.0},
#   {'id': 'DrToq9357afdpOyO5w0Y5w',
#    'name': 'Yup Dduk LA',
#    'review_count': 2187,
#    'rating': 4.5},
#   {'id': 'AIhWsp8yNfKZfaX9d9Yajg',
#    'name': 'Pasta Sisters',
#    'review_count': 1690,
#    'rating': 4.5},
#   {'id': 'TWHGJkTAbF22hvXeReQp9w',
#    'name': 'Kobawoo House',
#    'review_count': 1275,
#    'rating': 4.5},
#   {'id': '3C2wUqSkpY4-N0O5ArVjwQ',
#    'name': 'Yuk Dae Jang',
#    'review_count': 624,
#    'rating': 4.5},
#   {'id': 'MlmcOkwaNnxl3Zuk6HsPCQ',
#    'name': "Slurpin' Ramen Bar - Los Angeles",
#    'review_count': 4846,
#    'rating': 4.5},
#   {'id': 'kdTFcDSl9vAR-btEm1Q2uw',
#    'name': 'Bao Dim Sum House',
#    'review_count': 3151,
#    'rating': 4.0},
#   {'id': 'rr-hXB0ZqXLzUP97yftp0g',
#    'name': 'Osteria Mamma',
#    'review_count': 1717,
#    'rating': 4.0},
#   {'id': 'GKQApReu8U9hip4A2ApJ_A',
#    'name': 'Osteria La Buca',
#    'review_count': 2035,
#    'rating': 4.0},
#   {'id': 'BSUDJiaKZwbB8G-GTUst_g',
#    'name': 'Beauty & Essex',
#    'review_count': 1235,
#    'rating': 4.0},
#   {'id': 'UXHxLN3DcDGI57uDIfCuJA',
#    'name': "Old's Havana Cuban Bar & Cocina",
#    'review_count': 1387,
#    'rating': 4.5},
#   {'id': 'SyVrRDKTGgVGNSNAbngxfw',
#    'name': 'Glass & Vine',
#    'review_count': 1122,
#    'rating': 4.0},
#   {'id': 'opz-z4k-WK0KsyyR1Vwg5A',
#    'name': 'WHISK Gourmet Food & Catering',
#    'review_count': 1253,
#    'rating': 4.5},
#   {'id': '-b4dNNCCsDMtidBcGtlM7g',
#    'name': 'Honey Uninhibited',
#    'review_count': 1126,
#    'rating': 4.0},
#   {'id': 's4LuSZ5F_1R2mRb3pOHNbQ',
#    'name': 'Mamey - Miami',
#    'review_count': 264,
#    'rating': 4.5},
#   {'id': 'O4gh_gZPp1zW9QtC1aMHWw',
#    'name': 'House of Food Porn',
#    'review_count': 102,
#    'rating': 5.0},
#   {'id': 'ix8ifP1jQM9ektdVAs19sQ',
#    'name': 'Crazy About You',
#    'review_count': 1853,
#    'rating': 4.0},
#   {'id': '_tMXqt6aeU_UajCi-Gov1Q',
#    'name': 'Black Market Miami',
#    'review_count': 304,
#    'rating': 4.0},
#   {'id': '1h8-r9cLeXxW99HhlRUnlA',
#    'name': 'CVI.CHE 105',
#    'review_count': 4269,
#    'rating': 4.5},
#   {'id': 'hZ66PVSH6Miscv2n8KxAEg',
#    'name': 'Greenstreet Cafe',
#    'review_count': 1914,
#    'rating': 4.0},
#   {'id': 'WLXQNtdVm0sPbJ3MvCIyBw',
#    'name': 'B Bistro At The Grove',
#    'review_count': 3,
#    'rating': 5.0},
#   {'id': 'V3btCvWa1flTBYt2YKea_g',
#    'name': 'Bombay Darbar',
#    'review_count': 1212,
#    'rating': 4.5},
#   {'id': 'jp8y_UlQW8KE0yAcJ1Jubg',
#    'name': 'The Fatty Crab',
#    'review_count': 154,
#    'rating': 4.5},
#   {'id': 'YQbG-8223QKr-X_Yqu-bVw',
#    'name': 'Amigo Grill & Co, Casual Steakhouse',
#    'review_count': 119,
#    'rating': 4.5},
#   {'id': 'LnyDHTiXoPRSxk7e5qPl4w',
#    'name': 'CRAFT Coral Gables',
#    'review_count': 45,
#    'rating': 4.5},
#   {'id': 'Dzk_O70dBXoKcIQQeaOqyw',
#    'name': 'Amor di Pasta - Blue Lagoon',
#    'review_count': 294,
#    'rating': 4.5},
#   {'id': 'bqTmkGBOUV6ReXWk1BVa2w',
#    'name': 'Kush by Spillover',
#    'review_count': 898,
#    'rating': 4.5},
#   {'id': 'tGKkA2Ru_tfiQdHWIjUA1A',
#    'name': 'CHICA Miami',
#    'review_count': 496,
#    'rating': 4.0},
#   {'id': 'QQnw1bFxLyamuxn4giIy9g',
#    'name': 'Barbakoa by Finka',
#    'review_count': 55,
#    'rating': 4.5},
#   {'id': 'ADe7l7J_Cn4n6ptFNXW-tg',
#    'name': 'Cebada Rooftop',
#    'review_count': 36,
#    'rating': 4.5},
#   {'id': 'HHtpR0RslupSQ99GIIwW5A',
#    'name': 'Marufuku Ramen',
#    'review_count': 3478,
#    'rating': 4.5},
#   {'id': 'ttarnopezxmp2ROB1N2PaA',
#    'name': 'Nopa',
#    'review_count': 5158,
#    'rating': 4.0},
#   {'id': '-DrR38H1Abk0wCyu9XOLug',
#    'name': 'Sweet Maple',
#    'review_count': 4117,
#    'rating': 4.5},
#   {'id': 'f-m7-hyFzkf0HSEeQ2s-9A',
#    'name': 'Fog Harbor Fish House',
#    'review_count': 6941,
#    'rating': 4.5},
#   {'id': '8kck3-K4zYKTJbJko0JlXQ',
#    'name': 'Farmhouse Kitchen Thai Cuisine',
#    'review_count': 2969,
#    'rating': 4.0},
#   {'id': 'XhJ6ZYagcWNHpJ1H1KvNlQ',
#    'name': 'a Mano',
#    'review_count': 1155,
#    'rating': 4.0},
#   {'id': '8dUaybEPHsZMgr1iKgqgMQ',
#    'name': 'Sotto Mare Oysteria & Seafood',
#    'review_count': 4149,
#    'rating': 4.5},
#   {'id': 'XQLmEdXoMzOpffwoFaBtaQ',
#    'name': 'Kitchen Story',
#    'review_count': 3596,
#    'rating': 4.0},
#   {'id': '_hOVIgjVRl_HzvLaa65KJg',
#    'name': 'The Snug',
#    'review_count': 281,
#    'rating': 4.0},
#   {'id': 'MaaySW1ejpwQCkr9jn1glA',
#    'name': "The Tailor's Son",
#    'review_count': 131,
#    'rating': 4.0},
#   {'id': 'BjlVE7tTp1UCEttgkM1Big',
#    'name': 'Beit Rima',
#    'review_count': 466,
#    'rating': 4.5},
#   {'id': 'dY0Mc_PHH6nLENvWmVtwxQ',
#    'name': 'Daeho Kalbijjim & Beef Soup',
#    'review_count': 1158,
#    'rating': 4.5},
#   {'id': 'XAYwAF_83becwNnSJDFkpA',
#    'name': 'Dumpling House',
#    'review_count': 252,
#    'rating': 4.5},
#   {'id': 'AtFGQccBpgEZzsy9V1330Q',
#    'name': 'Lily',
#    'review_count': 159,
#    'rating': 4.5},
#   {'id': 'TlBFKt2N2eSEBpN-UZmDBw',
#    'name': 'Parada 22',
#    'review_count': 1302,
#    'rating': 4.0},
#   {'id': '8u7pyRsCdf0DOP-Vg6MuLQ',
#    'name': 'Purple Rice',
#    'review_count': 154,
#    'rating': 4.5},
#   {'id': 'd5752S_RDb26HxoL6O06eQ',
#    'name': 'Beit Rima',
#    'review_count': 132,
#    'rating': 4.5},
#   {'id': 'eYXwVR4mMAjzkJnm5wneHQ',
#    'name': 'Burma Superstar',
#    'review_count': 6976,
#    'rating': 4.0},
#   {'id': 'B09WOy0W83Od-Xw4xEXxog',
#    'name': 'Roma Antica',
#    'review_count': 895,
#    'rating': 4.5},
#   {'id': '0A_ZUL5r8wwL1oWnzmqSog',
#    'name': 'Komaaj',
#    'review_count': 123,
#    'rating': 5.0},
#   {'id': '0ggseJ7x1t-I-I8GA6knjw',
#    'name': 'Bistro 63',
#    'review_count': 183,
#    'rating': 4.0},
#   {'id': 'S9w52Y8f_nfv8QXuHmXBCg',
#    'name': "Johnny's Tavern",
#    'review_count': 317,
#    'rating': 4.0},
#   {'id': '1Gdcycg8N2j9oJbH1D6lBg',
#    'name': "Lili's Restaurant",
#    'review_count': 158,
#    'rating': 5.0},
#   {'id': '94j7QMjtGtLCNoXjca95Jw',
#    'name': 'Savannas Amherst Bar and Bistro',
#    'review_count': 5,
#    'rating': 5.0},
#   {'id': '1xHC1WbRBSv_DRRh8dP5IA',
#    'name': 'Honeycrisp Chicken',
#    'review_count': 65,
#    'rating': 4.5},
#   {'id': 'Ie-qeBdtdOavjzdQPH1IGw',
#    'name': 'Osteria Vespa',
#    'review_count': 94,
#    'rating': 4.0},
#   {'id': '1K-cj8tD7mHMuDxvkeI-xw',
#    'name': 'Omi Omy',
#    'review_count': 78,
#    'rating': 4.5},
#   {'id': 'LXXAXCEiU4nCM8wScorQHQ',
#    'name': 'Pasta E Basta',
#    'review_count': 151,
#    'rating': 4.0},
#   {'id': 'LcfGULHH5iJ5VkT9q04iMg',
#    'name': 'Oriental Flavor',
#    'review_count': 215,
#    'rating': 4.0},
#   {'id': 'hRoE_3CUPnxn_1oDjjd9Lg',
#    'name': 'Jakes at The Mill',
#    'review_count': 65,
#    'rating': 4.5},
#   {'id': '0_n0QgP_AookwqzVfZIFgQ',
#    'name': 'Mission Cantina',
#    'review_count': 340,
#    'rating': 4.0},
#   {'id': 't3ZQ2eUTL4c683gbP4fmjA',
#    'name': 'Wheelhouse',
#    'review_count': 14,
#    'rating': 4.5},
#   {'id': '2xvvqUWeYDsMgixuZCpyLQ',
#    'name': 'Hangar Pub & Grill',
#    'review_count': 147,
#    'rating': 3.5},
#   {'id': '1yFNsud2RmCzfogPNDTbNw',
#    'name': 'Gohyang Korean Restaurant',
#    'review_count': 64,
#    'rating': 4.0},
#   {'id': 'o766sCbxUEbiBxr14X4ryw',
#    'name': 'Formosa Chinese Restaurant',
#    'review_count': 60,
#    'rating': 4.0},
#   {'id': 'd1PfS_bozULtBY4PjF3D-w',
#    'name': "Antonio's",
#    'review_count': 493,
#    'rating': 4.5},
#   {'id': 'T-Ouo3opXRiUEyGoBT0aoA',
#    'name': 'The Harp Irish Pub',
#    'review_count': 33,
#    'rating': 4.0},
#   {'id': 'snV8jGHnoVWBNJyRUBJYug',
#    'name': 'Crazy Noodles',
#    'review_count': 108,
#    'rating': 4.0},
#   {'id': '6EIJiG73rc9zCZSXOrksbw',
#    'name': 'Kaiju',
#    'review_count': 70,
#    'rating': 3.5},
#   {'id': 'zwC34RoPsOM_j3-V05DYfQ',
#    'name': "Alina's Ristorante",
#    'review_count': 129,
#    'rating': 4.0}],
#  'total_reviews': 171037}

# %%
chicago_res = open('chicago.json', 'r')
values = json.load(chicago_res)
chicago_res.close()

for field in values['businesses']:
    data["total_reviews"] += field["review_count"]
    res_info = {"id": None, "name": None, "review_count": None, "rating": None}
    for key,value in field.items():
        if key in res_info.keys():
            res_info[key] = value
    data["businesses"].append(res_info)
data
# Out:
# {'businesses': [{'id': 'sA2gVTJOBH7Qk32p48ENdQ',
#    'name': 'Saltie Girl',
#    'review_count': 1368,
#    'rating': 4.5},
#   {'id': 'kP1b-7BO_VhWk_0tvuA_tw',
#    'name': "Carmelina's",
#    'review_count': 2491,
#    'rating': 4.5},
#   {'id': 'xlOMKjE4omTgkI1eduWj8A',
#    'name': 'The Friendly Toast',
#    'review_count': 2038,
#    'rating': 4.0},
#   {'id': 'tKRg7pxR2Sw7aSrHTQS5mQ',
#    'name': 'Buttermilk & Bourbon',
#    'review_count': 729,
#    'rating': 4.0},
#   {'id': 'y2w6rFaO0XEiG5mFfOsiFA',
#    'name': 'Neptune Oyster',
#    'review_count': 5386,
#    'rating': 4.5},
#   {'id': 't_FFcwUutj9mIYKGw_gHsQ',
#    'name': 'The Salty Pig',
#    'review_count': 1711,
#    'rating': 4.0},
#   {'id': 'lCMN0raxlHnBFDoLgkz4sw',
#    'name': 'Milkweed',
#    'review_count': 793,
#    'rating': 4.0},
#   {'id': 'kb0VfKZKHHhvDze3JZqi0Q',
#    'name': 'Q Restaurant',
#    'review_count': 1152,
#    'rating': 4.0},
#   {'id': 'EbUZhM4fLpsWQ8fpBhhgEQ',
#    'name': "Mike & Patty's - Boston",
#    'review_count': 1867,
#    'rating': 4.5},
#   {'id': 'NYa-JphaaB41ElGsb3iawA',
#    'name': 'Toro',
#    'review_count': 2255,
#    'rating': 4.0},
#   {'id': 'lPAzwB4vPBqZmaFNH90kiQ',
#    'name': 'Cafe Bonjour',
#    'review_count': 319,
#    'rating': 4.5},
#   {'id': '2u_w3rthRzR2uEihW5BC4A',
#    'name': "Giacomo's Ristorante - Boston",
#    'review_count': 3669,
#    'rating': 4.0},
#   {'id': '9gtpqrz-5bLzf6SlhYI3vA',
#    'name': 'Nagomi Izakaya',
#    'review_count': 11,
#    'rating': 4.5},
#   {'id': 'nyy38msunExaObJOeH7j0Q',
#    'name': 'Bootleg Special',
#    'review_count': 778,
#    'rating': 4.0},
#   {'id': 'uXOVFQraz1va1TrtgiqYTg',
#    'name': 'The Daily Catch',
#    'review_count': 1719,
#    'rating': 4.0},
#   {'id': 'mP1EdIafQKMuOm9O4PzAfA',
#    'name': 'Barcelona Wine Bar South End',
#    'review_count': 1190,
#    'rating': 4.5},
#   {'id': 'E3Qqa99qFy1oeGMv0wPBBQ',
#    'name': 'Tora Japanese Restaurant',
#    'review_count': 518,
#    'rating': 4.5},
#   {'id': 'nIS4O-TwLYkA_P1Cu0SfhA',
#    'name': "Yvonne's",
#    'review_count': 1096,
#    'rating': 4.0},
#   {'id': 'AGR_kBvN__I7aTl0rBywAg',
#    'name': 'Atlantic Fish Co',
#    'review_count': 2720,
#    'rating': 4.0},
#   {'id': 'xZ22_0eJOgaiKqIhoSHrPw',
#    'name': 'Bostonia Public House',
#    'review_count': 1565,
#    'rating': 4.0},
#   {'id': 'fVbUVAiLiGgLA_nxBFxyww',
#    'name': 'Thursday Kitchen',
#    'review_count': 1478,
#    'rating': 4.5},
#   {'id': 'J3NT61-AH5d5Gu5tFJhYSw',
#    'name': 'The Cabin NYC',
#    'review_count': 353,
#    'rating': 4.0},
#   {'id': 'qEe7nIhPfEL6L0-VYhWRrA',
#    'name': 'Raku',
#    'review_count': 555,
#    'rating': 4.5},
#   {'id': '0CjK3esfpFcxIopebzjFxA',
#    'name': "Joe's Shanghai",
#    'review_count': 6495,
#    'rating': 4.0},
#   {'id': 'ETgJqJHV7BW6pIr9Ox74sA',
#    'name': 'Amélie',
#    'review_count': 2759,
#    'rating': 4.5},
#   {'id': 'B3_K2kUVbYOU0VaLcj_LTw',
#    'name': 'Thai Villa',
#    'review_count': 3890,
#    'rating': 4.5},
#   {'id': 'FlZ1zdVEKWv7dwqm8Uw8-w',
#    'name': 'Raku',
#    'review_count': 1227,
#    'rating': 4.5},
#   {'id': 'liZmIO0FqZwslLJfLDkfgw',
#    'name': 'Wayla',
#    'review_count': 420,
#    'rating': 4.5},
#   {'id': 'jjJc_CrkB2HodEinB6cWww',
#    'name': 'LoveMama',
#    'review_count': 5622,
#    'rating': 4.5},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'name': 'Rubirosa',
#    'review_count': 2489,
#    'rating': 4.5},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'name': "Juliana's",
#    'review_count': 2355,
#    'rating': 4.5},
#   {'id': 'uoT2_Wrt1noD6kZOID7tUg',
#    'name': 'Jane',
#    'review_count': 3239,
#    'rating': 4.0},
#   {'id': 'hdiuRS9sVZSMReZm4oV5SA',
#    'name': 'Da Andrea',
#    'review_count': 1013,
#    'rating': 4.0},
#   {'id': '16ZnHpuaaBt92XWeJHCC5A',
#    'name': 'Olio e Piú',
#    'review_count': 2892,
#    'rating': 4.5},
#   {'id': 'aZ_a78wVWnQnV6BdMwcFVA',
#    'name': 'YUBU',
#    'review_count': 110,
#    'rating': 4.5},
#   {'id': '8SehQovJOuQDLbtzLLYLyw',
#    'name': 'RH Rooftop Restaurant New York',
#    'review_count': 487,
#    'rating': 4.0},
#   {'id': 'nHMDOIX32dGbfpuNUwsLNQ',
#    'name': 'AlMar',
#    'review_count': 462,
#    'rating': 4.0},
#   {'id': '4FD0TAxe70nb3ngk3sXF9Q',
#    'name': 'Uluh',
#    'review_count': 561,
#    'rating': 4.5},
#   {'id': '9fG8-RRh1rzuCKN2TmF-QQ',
#    'name': '5ive Spice',
#    'review_count': 435,
#    'rating': 4.5},
#   {'id': 'gtXP0CmOnBbgfnff7VXa7A',
#    'name': 'Pastis',
#    'review_count': 316,
#    'rating': 4.0},
#   {'id': 'z0zaCVA-p_5xTsyUZrmR0g',
#    'name': 'Republique',
#    'review_count': 5954,
#    'rating': 4.0},
#   {'id': '88kri8FhXy8b3DQ_QjSMmQ',
#    'name': "L'Antica Pizzeria Da Michele",
#    'review_count': 1137,
#    'rating': 4.5},
#   {'id': 'h1R2iKYdm2lwukzMJvJqDw',
#    'name': 'Hangari Kalguksu',
#    'review_count': 1896,
#    'rating': 4.5},
#   {'id': '25fipMHUHLZTq0sVQINi5g',
#    'name': 'The Front Yard',
#    'review_count': 2575,
#    'rating': 4.0},
#   {'id': 'WO12S4gvOYkYF8_70RWrQA',
#    'name': 'HanEuem',
#    'review_count': 50,
#    'rating': 4.5},
#   {'id': 'h2u-coGd8WWClyU3b7jf8w',
#    'name': 'Met Her At A Bar',
#    'review_count': 1856,
#    'rating': 4.5},
#   {'id': 'RVbZaawgEGmto6TxOoVBdQ',
#    'name': 'Running Goose',
#    'review_count': 1205,
#    'rating': 4.5},
#   {'id': 'cal0Wpupxj9c_AV7WzDXsw',
#    'name': 'GRANVILLE',
#    'review_count': 1717,
#    'rating': 4.5},
#   {'id': 'HuQtriV_ApipXfM8xax33w',
#    'name': 'Met Him At A Bar',
#    'review_count': 313,
#    'rating': 4.5},
#   {'id': 'fCfkMf27m2PcTWXLTrLM7Q',
#    'name': 'Fratelli Cafe',
#    'review_count': 1720,
#    'rating': 4.5},
#   {'id': 'wvaNbC16NuJIQD0g8WPjRw',
#    'name': 'TOKKI - Korean Tapas',
#    'review_count': 35,
#    'rating': 5.0},
#   {'id': 'DrToq9357afdpOyO5w0Y5w',
#    'name': 'Yup Dduk LA',
#    'review_count': 2187,
#    'rating': 4.5},
#   {'id': 'AIhWsp8yNfKZfaX9d9Yajg',
#    'name': 'Pasta Sisters',
#    'review_count': 1690,
#    'rating': 4.5},
#   {'id': 'TWHGJkTAbF22hvXeReQp9w',
#    'name': 'Kobawoo House',
#    'review_count': 1275,
#    'rating': 4.5},
#   {'id': '3C2wUqSkpY4-N0O5ArVjwQ',
#    'name': 'Yuk Dae Jang',
#    'review_count': 624,
#    'rating': 4.5},
#   {'id': 'MlmcOkwaNnxl3Zuk6HsPCQ',
#    'name': "Slurpin' Ramen Bar - Los Angeles",
#    'review_count': 4846,
#    'rating': 4.5},
#   {'id': 'kdTFcDSl9vAR-btEm1Q2uw',
#    'name': 'Bao Dim Sum House',
#    'review_count': 3151,
#    'rating': 4.0},
#   {'id': 'rr-hXB0ZqXLzUP97yftp0g',
#    'name': 'Osteria Mamma',
#    'review_count': 1717,
#    'rating': 4.0},
#   {'id': 'GKQApReu8U9hip4A2ApJ_A',
#    'name': 'Osteria La Buca',
#    'review_count': 2035,
#    'rating': 4.0},
#   {'id': 'BSUDJiaKZwbB8G-GTUst_g',
#    'name': 'Beauty & Essex',
#    'review_count': 1235,
#    'rating': 4.0},
#   {'id': 'UXHxLN3DcDGI57uDIfCuJA',
#    'name': "Old's Havana Cuban Bar & Cocina",
#    'review_count': 1387,
#    'rating': 4.5},
#   {'id': 'SyVrRDKTGgVGNSNAbngxfw',
#    'name': 'Glass & Vine',
#    'review_count': 1122,
#    'rating': 4.0},
#   {'id': 'opz-z4k-WK0KsyyR1Vwg5A',
#    'name': 'WHISK Gourmet Food & Catering',
#    'review_count': 1253,
#    'rating': 4.5},
#   {'id': '-b4dNNCCsDMtidBcGtlM7g',
#    'name': 'Honey Uninhibited',
#    'review_count': 1126,
#    'rating': 4.0},
#   {'id': 's4LuSZ5F_1R2mRb3pOHNbQ',
#    'name': 'Mamey - Miami',
#    'review_count': 264,
#    'rating': 4.5},
#   {'id': 'O4gh_gZPp1zW9QtC1aMHWw',
#    'name': 'House of Food Porn',
#    'review_count': 102,
#    'rating': 5.0},
#   {'id': 'ix8ifP1jQM9ektdVAs19sQ',
#    'name': 'Crazy About You',
#    'review_count': 1853,
#    'rating': 4.0},
#   {'id': '_tMXqt6aeU_UajCi-Gov1Q',
#    'name': 'Black Market Miami',
#    'review_count': 304,
#    'rating': 4.0},
#   {'id': '1h8-r9cLeXxW99HhlRUnlA',
#    'name': 'CVI.CHE 105',
#    'review_count': 4269,
#    'rating': 4.5},
#   {'id': 'hZ66PVSH6Miscv2n8KxAEg',
#    'name': 'Greenstreet Cafe',
#    'review_count': 1914,
#    'rating': 4.0},
#   {'id': 'WLXQNtdVm0sPbJ3MvCIyBw',
#    'name': 'B Bistro At The Grove',
#    'review_count': 3,
#    'rating': 5.0},
#   {'id': 'V3btCvWa1flTBYt2YKea_g',
#    'name': 'Bombay Darbar',
#    'review_count': 1212,
#    'rating': 4.5},
#   {'id': 'jp8y_UlQW8KE0yAcJ1Jubg',
#    'name': 'The Fatty Crab',
#    'review_count': 154,
#    'rating': 4.5},
#   {'id': 'YQbG-8223QKr-X_Yqu-bVw',
#    'name': 'Amigo Grill & Co, Casual Steakhouse',
#    'review_count': 119,
#    'rating': 4.5},
#   {'id': 'LnyDHTiXoPRSxk7e5qPl4w',
#    'name': 'CRAFT Coral Gables',
#    'review_count': 45,
#    'rating': 4.5},
#   {'id': 'Dzk_O70dBXoKcIQQeaOqyw',
#    'name': 'Amor di Pasta - Blue Lagoon',
#    'review_count': 294,
#    'rating': 4.5},
#   {'id': 'bqTmkGBOUV6ReXWk1BVa2w',
#    'name': 'Kush by Spillover',
#    'review_count': 898,
#    'rating': 4.5},
#   {'id': 'tGKkA2Ru_tfiQdHWIjUA1A',
#    'name': 'CHICA Miami',
#    'review_count': 496,
#    'rating': 4.0},
#   {'id': 'QQnw1bFxLyamuxn4giIy9g',
#    'name': 'Barbakoa by Finka',
#    'review_count': 55,
#    'rating': 4.5},
#   {'id': 'ADe7l7J_Cn4n6ptFNXW-tg',
#    'name': 'Cebada Rooftop',
#    'review_count': 36,
#    'rating': 4.5},
#   {'id': 'HHtpR0RslupSQ99GIIwW5A',
#    'name': 'Marufuku Ramen',
#    'review_count': 3478,
#    'rating': 4.5},
#   {'id': 'ttarnopezxmp2ROB1N2PaA',
#    'name': 'Nopa',
#    'review_count': 5158,
#    'rating': 4.0},
#   {'id': '-DrR38H1Abk0wCyu9XOLug',
#    'name': 'Sweet Maple',
#    'review_count': 4117,
#    'rating': 4.5},
#   {'id': 'f-m7-hyFzkf0HSEeQ2s-9A',
#    'name': 'Fog Harbor Fish House',
#    'review_count': 6941,
#    'rating': 4.5},
#   {'id': '8kck3-K4zYKTJbJko0JlXQ',
#    'name': 'Farmhouse Kitchen Thai Cuisine',
#    'review_count': 2969,
#    'rating': 4.0},
#   {'id': 'XhJ6ZYagcWNHpJ1H1KvNlQ',
#    'name': 'a Mano',
#    'review_count': 1155,
#    'rating': 4.0},
#   {'id': '8dUaybEPHsZMgr1iKgqgMQ',
#    'name': 'Sotto Mare Oysteria & Seafood',
#    'review_count': 4149,
#    'rating': 4.5},
#   {'id': 'XQLmEdXoMzOpffwoFaBtaQ',
#    'name': 'Kitchen Story',
#    'review_count': 3596,
#    'rating': 4.0},
#   {'id': '_hOVIgjVRl_HzvLaa65KJg',
#    'name': 'The Snug',
#    'review_count': 281,
#    'rating': 4.0},
#   {'id': 'MaaySW1ejpwQCkr9jn1glA',
#    'name': "The Tailor's Son",
#    'review_count': 131,
#    'rating': 4.0},
#   {'id': 'BjlVE7tTp1UCEttgkM1Big',
#    'name': 'Beit Rima',
#    'review_count': 466,
#    'rating': 4.5},
#   {'id': 'dY0Mc_PHH6nLENvWmVtwxQ',
#    'name': 'Daeho Kalbijjim & Beef Soup',
#    'review_count': 1158,
#    'rating': 4.5},
#   {'id': 'XAYwAF_83becwNnSJDFkpA',
#    'name': 'Dumpling House',
#    'review_count': 252,
#    'rating': 4.5},
#   {'id': 'AtFGQccBpgEZzsy9V1330Q',
#    'name': 'Lily',
#    'review_count': 159,
#    'rating': 4.5},
#   {'id': 'TlBFKt2N2eSEBpN-UZmDBw',
#    'name': 'Parada 22',
#    'review_count': 1302,
#    'rating': 4.0},
#   {'id': '8u7pyRsCdf0DOP-Vg6MuLQ',
#    'name': 'Purple Rice',
#    'review_count': 154,
#    'rating': 4.5},
#   {'id': 'd5752S_RDb26HxoL6O06eQ',
#    'name': 'Beit Rima',
#    'review_count': 132,
#    'rating': 4.5},
#   {'id': 'eYXwVR4mMAjzkJnm5wneHQ',
#    'name': 'Burma Superstar',
#    'review_count': 6976,
#    'rating': 4.0},
#   {'id': 'B09WOy0W83Od-Xw4xEXxog',
#    'name': 'Roma Antica',
#    'review_count': 895,
#    'rating': 4.5},
#   {'id': '0A_ZUL5r8wwL1oWnzmqSog',
#    'name': 'Komaaj',
#    'review_count': 123,
#    'rating': 5.0},
#   {'id': '0ggseJ7x1t-I-I8GA6knjw',
#    'name': 'Bistro 63',
#    'review_count': 183,
#    'rating': 4.0},
#   {'id': 'S9w52Y8f_nfv8QXuHmXBCg',
#    'name': "Johnny's Tavern",
#    'review_count': 317,
#    'rating': 4.0},
#   {'id': '1Gdcycg8N2j9oJbH1D6lBg',
#    'name': "Lili's Restaurant",
#    'review_count': 158,
#    'rating': 5.0},
#   {'id': '94j7QMjtGtLCNoXjca95Jw',
#    'name': 'Savannas Amherst Bar and Bistro',
#    'review_count': 5,
#    'rating': 5.0},
#   {'id': '1xHC1WbRBSv_DRRh8dP5IA',
#    'name': 'Honeycrisp Chicken',
#    'review_count': 65,
#    'rating': 4.5},
#   {'id': 'Ie-qeBdtdOavjzdQPH1IGw',
#    'name': 'Osteria Vespa',
#    'review_count': 94,
#    'rating': 4.0},
#   {'id': '1K-cj8tD7mHMuDxvkeI-xw',
#    'name': 'Omi Omy',
#    'review_count': 78,
#    'rating': 4.5},
#   {'id': 'LXXAXCEiU4nCM8wScorQHQ',
#    'name': 'Pasta E Basta',
#    'review_count': 151,
#    'rating': 4.0},
#   {'id': 'LcfGULHH5iJ5VkT9q04iMg',
#    'name': 'Oriental Flavor',
#    'review_count': 215,
#    'rating': 4.0},
#   {'id': 'hRoE_3CUPnxn_1oDjjd9Lg',
#    'name': 'Jakes at The Mill',
#    'review_count': 65,
#    'rating': 4.5},
#   {'id': '0_n0QgP_AookwqzVfZIFgQ',
#    'name': 'Mission Cantina',
#    'review_count': 340,
#    'rating': 4.0},
#   {'id': 't3ZQ2eUTL4c683gbP4fmjA',
#    'name': 'Wheelhouse',
#    'review_count': 14,
#    'rating': 4.5},
#   {'id': '2xvvqUWeYDsMgixuZCpyLQ',
#    'name': 'Hangar Pub & Grill',
#    'review_count': 147,
#    'rating': 3.5},
#   {'id': '1yFNsud2RmCzfogPNDTbNw',
#    'name': 'Gohyang Korean Restaurant',
#    'review_count': 64,
#    'rating': 4.0},
#   {'id': 'o766sCbxUEbiBxr14X4ryw',
#    'name': 'Formosa Chinese Restaurant',
#    'review_count': 60,
#    'rating': 4.0},
#   {'id': 'd1PfS_bozULtBY4PjF3D-w',
#    'name': "Antonio's",
#    'review_count': 493,
#    'rating': 4.5},
#   {'id': 'T-Ouo3opXRiUEyGoBT0aoA',
#    'name': 'The Harp Irish Pub',
#    'review_count': 33,
#    'rating': 4.0},
#   {'id': 'snV8jGHnoVWBNJyRUBJYug',
#    'name': 'Crazy Noodles',
#    'review_count': 108,
#    'rating': 4.0},
#   {'id': '6EIJiG73rc9zCZSXOrksbw',
#    'name': 'Kaiju',
#    'review_count': 70,
#    'rating': 3.5},
#   {'id': 'zwC34RoPsOM_j3-V05DYfQ',
#    'name': "Alina's Ristorante",
#    'review_count': 129,
#    'rating': 4.0},
#   {'id': 'okaqMJEoHfHblpKz9Q-CMA',
#    'name': 'The Perch',
#    'review_count': 220,
#    'rating': 4.5},
#   {'id': 'zm6Peew9j8YtowzUu4sQfA',
#    'name': 'The Whale Chicago',
#    'review_count': 598,
#    'rating': 4.0},
#   {'id': 'W2QV6SILHer3qB_-CZ1z1A',
#    'name': 'etta - Bucktown',
#    'review_count': 787,
#    'rating': 4.5},
#   {'id': 'wfkj7DK8YzhdwhhFc2OntA',
#    'name': 'Giant',
#    'review_count': 500,
#    'rating': 4.5},
#   {'id': 'qUhMEd8oDAwGqBEF9mNKFQ',
#    'name': 'Andros Taverna',
#    'review_count': 107,
#    'rating': 4.5},
#   {'id': 'vLNDwB7xaqE5OsmZ0Y3gng',
#    'name': 'Salt Burgers + Fries',
#    'review_count': 30,
#    'rating': 4.0},
#   {'id': 'qjnpkS8yZO8xcyEIy5OU9A',
#    'name': 'Girl & The Goat',
#    'review_count': 8900,
#    'rating': 4.5},
#   {'id': 'faOpq9ORL0FlsMrou2NYug',
#    'name': 'Amaru',
#    'review_count': 214,
#    'rating': 5.0},
#   {'id': '0IYXh7l_VppKw5y97FehoA',
#    'name': 'Kasama',
#    'review_count': 139,
#    'rating': 4.5},
#   {'id': 'f3mkFF9TW4nSSCmHw3N97A',
#    'name': 'Testaccio',
#    'review_count': 63,
#    'rating': 4.5},
#   {'id': 'iOMvXQYFl6_mtw0wX6ZUXw',
#    'name': 'Forbidden Root',
#    'review_count': 499,
#    'rating': 4.5},
#   {'id': 'ssO_Xo9bhQcgyAH9UEQJXQ',
#    'name': 'Ørkenoy',
#    'review_count': 30,
#    'rating': 5.0},
#   {'id': 'm5_GCJP2W4zEJnyVgxa3eA',
#    'name': 'Longman & Eagle',
#    'review_count': 2446,
#    'rating': 4.0},
#   {'id': 'WUK_G_6ECozMtnJX3YVdIg',
#    'name': 'Machine: Engineered Dining & Drink',
#    'review_count': 460,
#    'rating': 4.0},
#   {'id': 'boE4Ahsssqic7o5wQLI04w',
#    'name': 'The Purple Pig',
#    'review_count': 7426,
#    'rating': 4.0},
#   {'id': '87bmC0ZQ3pVU-wxRGtRkkQ',
#    'name': 'Sushi + Rotary Sushi Bar - Chinatown',
#    'review_count': 179,
#    'rating': 4.5},
#   {'id': 'apo9fX6Opmr2Z87sm-_cfg',
#    'name': 'All Together Now',
#    'review_count': 76,
#    'rating': 4.5},
#   {'id': 'TBCNrNW2WY4kuvg9LybEFA',
#    'name': 'Funkenhausen',
#    'review_count': 232,
#    'rating': 4.5},
#   {'id': 'kuJLjqq0m_tWfkgkMV6WrA',
#    'name': 'Sweet Rice Asian Kitchen',
#    'review_count': 7,
#    'rating': 5.0},
#   {'id': 'nnP8axu680aDGPdQ4TuSkA',
#    'name': 'Wake ‘n Bacon',
#    'review_count': 176,
#    'rating': 4.5}],
#  'total_reviews': 194126}

# %%
with open('more_data.json', 'w', encoding='utf-8') as f:
    json.dump(data, f, ensure_ascii=False, indent=4)
